# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def search():
    x = input('Enter a term: ')
    page = requests.get('https://www.googleapis.com/customsearch/v1?key=AIzaSyDVhLo7i5TgaK3l8-JTKLJiseGigIt2OHI&cx=016511908903761797842:olhvobwt9sd=' + x)
    data = page.json()
    t = len(data['items'])
    for i in range(t):
        print(data['items'][i]['link'])

# %%
search()
# Out:
# Enter a term: aditya
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-5a2c6e8a5986> in <module>
# ----> 1 search()
#
# <ipython-input-11-0d73bd2e07af> in search()
#       3     page = requests.get('https://www.googleapis.com/customsearch/v1?key=AIzaSyDVhLo7i5TgaK3l8-JTKLJiseGigIt2OHI&cx=016511908903761797842:olhvobwt9sd=' + x)
#       4     data = page.json()
# ----> 5     t = len(data['items'])
#       6     for i in range(t):
#       7         print(data['items'][i]['link'])
#
# KeyError: 'items'

# %%
x = 'adityachavan198@gmail.com'
page = requests.get('https://www.bing.com/search?q='+ x)
soup = BeautifulSoup(page.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:web="http://schemas.live.com/Web/"><head><script type="text/javascript">//<![CDATA[
# si_ST=new Date
# //]]></script><!--pc--><title>adityachavan198@gmail.com - Bing</title><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="origin-when-cross-origin" name="referrer"/><link href="/search?format=rss&amp;q=adityachavan198@gmail.com" rel="alternate" title="XML" type="text/xml"/><link href="/search?format=rss&amp;q=adityachavan198@gmail.com" rel="alternate" title="RSS" type="application/rss+xml"/><link href="/sa/simg/bing_p_rr_teal_min.ico" rel="shortcut icon"/><script type="text/javascript">//<![CDATA[
# _G={ST:(si_ST?si_ST:new Date),Mkt:"en-US",RTL:false,Ver:"04",IG:"22A05FCB90C8402899DA5149BBE0E137",EventID:"DF85F17EAAD745CC9F6723A1D74E4D43",V:"web",P:"SERP",DA:"HKG01",CID:"2B61C71AB4CC601922A0C941B5736143",SUIH:"mV72zb-9nMAQaqrtlaqLjg",adc:"b_ad",gpUrl:"\/fd\/ls\/GLinkPing.aspx?" }; _G.lsUrl="/fd/ls/l?IG="+_G.IG+"&CID="+_G.CID ;curUrl="https:\/\/www.bing.com\/search";function si_T(a){ if(document.images){_G.GPImg=new Image;_G.GPImg.src=_G.gpUrl+'IG='+_G.IG+'&CID='+_G.CID+'&'+a;}return true;};/*!DisableJavascriptProfiler*/
# 0;
# ;/*!DisableJavascriptProfiler*/
# 0;/*!DisableJavascriptProfiler*/
# 0;
# ;
# //]]></script><style type="text/css">.sw_ddbk:after,.sw_ddw:after,.sw_ddgn:after,.sw_poi:after,.sw_poia:after,.sw_play:after,.sw_playa:after,.sw_playd:after,.sw_playp:after,.sw_st:after,.sw_sth:after,.sw_ste:after,.sw_st2:after,.sw_plus:after,.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after,.sw_arwh:after,.sb_pagN:after,.sb_pagP:after,.sw_up:after,.sw_down:after,.b_expandToggle:after,.sw_calc:after,.sw_fbi:after,.sw_twi:after,.b_fLogo:after,.b_cm:after,.sw_rmore:after,.sw_tpo:after,.sw_tpoa:after,.sw_lpoi:after,.sw_skp:after{position:relative;content:url(/sa/simg/SharedSpriteDesktop_2x_090619.png)}.sw_ddbk,.sw_ddw,.sw_ddgn,.sw_poi,.sw_poia,.sw_play,.sw_playa,.sw_playd,.sw_playp,.sw_st,.sw_sth,.sw_ste,.sw_st2,.sw_plus,.sw_tpcg,.sw_tpcw,.sw_tpcbk,.sw_arwh,.sb_pagN,.sb_pagP,.sw_up,.sw_down,.b_expandToggle,.sw_calc,.sw_fbi,.sw_twi,.b_fLogo,.b_cm,.sw_rmore,.sw_tpo,.sw_tpoa,.sw_lpoi,.sw_skp,.actExpander span{position:relative;display:inline-block;overflow:hidden;direction:ltr}.sw_ddbk:after,.sw_ddw:after,.sw_ddgn:after,.sw_poi:after,.sw_poia:after,.sw_play:after,.sw_playa:after,.sw_playd:after,.sw_playp:after,.sw_st:after,.sw_sth:after,.sw_ste:after,.sw_st2:after,.sw_plus:after,.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after,.sw_arwh:after,.sb_pagN:after,.sb_pagP:after,.sw_up:after,.sw_down:after,.b_expandToggle:after,.sw_calc:after,.sw_fbi:after,.sw_twi:after,.b_fLogo:after,.b_cm:after,.sw_rmore:after,.sw_tpo:after,.sw_tpoa:after,.sw_lpoi:after,.sw_skp:after{display:inline-block;transform:scale(.5)}.sw_tpcbk,.sw_tpcg,.b_expandToggle,.b_fLogo{display:block}.sw_play,.sw_playa,.sw_playd,.sw_playp,.sw_skp,.sw_fbi,.sw_twi{height:16px;width:16px}.sw_play:after{transform-origin:-630px -44px}.sw_playa:after{transform-origin:-666px -44px}.sw_playd:after{transform-origin:-702px -44px}.sw_playp:after{transform-origin:-738px -44px}.sw_skp:after{transform-origin:-1290px -36px}.sw_fbi:after{transform-origin:-594px -44px}.sw_twi:after{transform-origin:-1290px 0}.sw_st,.sw_sth,.sw_ste,.sw_st2{height:12px;width:12px}.sw_st:after{transform-origin:-1070px -62px}.sw_st2:after{transform-origin:-1126px -62px}.sw_sth:after{transform-origin:-1154px -62px}.sw_ste:after{transform-origin:-1098px -62px}.sw_arwh{height:11px;width:14px}a:hover .sw_arwh.b_invert:after{transform-origin:-926px -64px}.sw_arwh:after{transform-origin:-894px -64px}.sw_ddbk,.sw_ddw,.sw_ddgn{height:4px;width:7px}.sw_ddbk:after,.sw_ddw:after{transform-origin:-532px -64px}.sw_ddgn:after{transform-origin:-512px -64px}.sw_tpcg,.sw_tpcw,.sw_tpcbk{height:10px;width:10px}.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after{transform-origin:-352px -64px}.sw_tpcg:hover:after,.sw_tpcg:active:after,.sw_tpcg:focus:after{-webkit-transform-origin:-376px -64px;-ms-transform-origin:-376px -64px;transform-origin:-376px -64px}.sw_plus{height:8px;width:8px}.sw_plus:after{transform-origin:-552px -64px}.sw_plus:hover:after,.sw_plus:active:after,.sw_plus:focus:after{transform-origin:-572px -64px}.b_expandToggle,.sw_up,.sw_down{height:8px;width:12px}.b_expandToggle:after,.sw_up:after,.sw_down:after{transform-origin:-456px -64px}.sw_up:after{transform-origin:-400px -64px}*:hover>.sw_up:after,*:active>.sw_up:after,*:focus>.sw_up:after{transform-origin:-428px -64px}*:hover>.sw_down:after,*:active>.sw_down:after,*:focus>.sw_down:after{transform-origin:-484px -64px}.b_icon,.sw_poi,.sw_poia{width:20px;height:20px;z-index:0}.sw_poi:after,.sw_poia:after{position:absolute;top:0;left:0;transform-origin:-594px 0;z-index:-1}.sw_poia:after{transform-origin:-638px 0}.b_fLogo{height:16px;width:81px}.b_fLogo:after{transform-origin:-804px 0}.b_cm{height:10px;width:12px}.b_cm:after{transform-origin:-866px -64px}.sw_calc{height:19px;width:19px}.sw_calc:after{transform-origin:-726px 0}.sw_tpo,.sw_tpoa,.sw_rmore{height:12px;width:8px;display:block}.sw_tpo:after,.sw_tpoa:after{transform-origin:-262px -50px}.sw_rmore:after{transform-origin:-242px -50px}.sw_lpoi{height:16px;width:10px}.sw_lpoi:after{transform-origin:-1266px -36px}.b_ad .b_vlist ...
# var logMetaError=function(n){(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"CI.MetaError","FID":"CI","Name":"MetaJSError","Text":"'+escape(n)+'"}]'},getHref=function(){return location.href},regexEscape;try{regexEscape=function(n){return n.replace(/([.?*+^$&[\]\\(){}|<>-])/g,"\\$1")};function jsErrorHandler(n){var s,r,y,p,u,f,w,e,h,c,o;try{if(s="ERC",r=window[s],r=r?r+1:1,r===16&&(n=new Error("max errors reached")),r>16)return;window[s]=r;var l=n.error||n,b='"noMessage"',k=n.filename,d=n.lineno,g=n.colno,nt=n.extra,a=l.severity||"Error",tt=l.message||b,i=l.stack,t='"'+escape(tt.replace(/"/g,""))+'"',it=new RegExp(regexEscape(getHref()),"g");if(i){for(y=/\(([^\)]+):[0-9]+:[0-9]+\)/g,u={};(p=y.exec(i))!==null;)f=p[1],u[f]?u[f]++:u[f]=1;e=0;for(h in u)u[h]>1&&(c=regexEscape(h),w=new RegExp(c,"g"),i=i.replace(w,e),i+="#"+e+"="+c,e++);i=i.replace(it,"self").replace(/"/g,"");t+=',"Stack":"'+(escape(i)+'"')}if(k&&(t+=',"Meta":"'+escape(k.replace(it,"self"))+'"'),d&&(t+=',"Line":"'+d+'"'),g&&(t+=',"Char":"'+g+'"'),nt&&(t+=',"ExtraInfo":"'+nt+'"'),tt===b)if(a="Warning",t+=',"ObjectToString":"'+n.toString()+'"',JSON&&JSON.stringify)t+=',"JSON":"'+escape(JSON.stringify(n))+'"';else for(o in n)n.hasOwnProperty(o)&&(t+=',"'+o+'":"'+n[o]+'"');var rt=(new Date).getTime(),ut='"T":"CI.'+a+'","FID":"CI","Name":"JS'+a+'","Text":'+t+"",ft="<E><T>Event.ClientInst<\/T><IG>"+_G.IG+"<\/IG><TS>"+rt+"<\/TS><D><![CDATA[[{"+ut+"}]]\]><\/D><\/E>",et="<ClientInstRequest><Events>"+ft+"<\/Events><STS>"+rt+"<\/STS><\/ClientInstRequest>",v=new XMLHttpRequest;v.open("POST","/fd/ls/lsp.aspx?",!0);v.setRequestHeader("Content-Type","text/xml");v.send(et);typeof sj_evt!="undefined"&&sj_evt.fire("ErrorInstrumentation",t)}catch(ot){logMetaError("Failed to execute error handler. "+ot.message)}}window.addEventListener&&window.addEventListener("error",jsErrorHandler,!1);window.addEventListener||window.onerror||(window.onerror=function(n,t,i,r,u){var f="",e;typeof n=="object"&&n.srcElement&&n.srcElement.src?f="\"ScriptSrc = '"+escape(n.srcElement.src.replace(/'/g,""))+"'\"":(n=""+n,f='"'+escape(n.replace(/"/g,""))+'","Meta":"'+escape(t)+'","Line":'+i+',"Char": '+r,u&&u.stack&&(e=new RegExp(regexEscape(getHref()),"g"),f+=',"Stack":"'+escape(u.stack.replace(e,"self").replace(/"/g,"")+'"')));(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"CI.GetError","FID":"CI","Name":"JSGetError","Text":'+f+"}]";typeof sj_evt!="undefined"&&sj_evt.fire("ErrorInstrumentation",f)})}catch(e){logMetaError("Failed to bind error handler "+e.message)};var amd,define,require;(function(n){function e(n,i,u){t[n]||(t[n]={dependencies:i,callback:u},r(n))}function r(n){if(n){if(n)return u(n)}else{if(!f){for(var r in t)u(r);f=!0}return i}}function u(n){var s,e;if(i[n])return i[n];if(t.hasOwnProperty(n)){var h=t[n],f=h.dependencies,l=h.callback,a=r,o={},c=[a,o];if(f.length<2)throw"invalid usage";else if(f.length>2)for(s=f.slice(2,f.length),e=0;e<s.length;e++)c.push(u(s[e]));return l.apply(this,c),i[n]=o,o}}var t={},i={},f=!1;n.define=e;n.require=r})(amd||(amd={}));define=amd.define;require=amd.require;var _w=window,_d=document,sb_ie=window.ActiveXObject!==undefined,sb_i6=sb_ie&&!_w.XMLHttpRequest,_ge=function(n){return _d.getElementById(n)},_qs=function(n,t){return t=typeof t=="undefined"?_d:t,t.querySelector?t.querySelector(n):null},sb_st=function(n,t){return setTimeout(n,t)},sb_rst=sb_st,sb_ct=function(n){clearTimeout(n)},sb_gt=function(){return(new Date).getTime()},sj_gx=function(){return sb_i6?new ActiveXObject("MSXML2.XMLHTTP"):new XMLHttpRequest};_w.sj_ce=function(n,t,i){var r=_d.createElement(n);return t&&(r.id=t),i&&(r.className=i),r};_w.sj_cook={get:function(n,t){var i=_d.cookie.match(new RegExp("\\b"+n+"=[^;]+")),r;return t&&i?(r=i[0].match(new RegExp("\\b"+t+"=([^&]*)")),r?r[1]:null):i?i[0]:null}};_w.sk_merge||(_w.sk_merge=function(n){_d.cookie=n});define("fallback",["require","exports"],function(n,t){function f(){return function(){for(var r,h,c,t=[],n=0;n<arguments.l ...
# 0;/*!DisableJavascriptProfiler*/
# 0;/*!DisableJavascriptProfiler*/
# 0;ClTrCo={furl:!0};var ctcc=0,clc=_w.ClTrCo||{};_w.si_ct=function(n,t,i,r){var u,e,f,o,s,h,c;if(clc.SharedClickSuppressed)return!0;u="getAttribute";try{for(;n!==document.body;n=n.parentNode){if(!n||n===document||n[u]("data-noct"))break;if(e=(n.tagName==="A"||n[u]("data-clicks"))&&(n[u]("h")||n[u]("data-h"))||n[u]("_ct"),e){f=n[u]("_ctf");o=-1;i&&(i.type==="keydown"?o=-2:i.button!=null&&(o=i.button));f&&_w[f]||(f="si_T");f==="si_T"&&(s=encodeURIComponent(n[u]("href")),clc.furl&&!n[u]("data-private")?e+="&url="+s:clc.mfurl&&(e+="&abc="+s));r&&(e+="&source="+r);h="";clc.mc&&(h="&c="+ctcc++);c="&"+e+h;_w.si_sbwu(c)||_w[f]&&_w[f](c,n,i,o);break}if(t)break}}catch(l){_w.SharedLogHelper?SharedLogHelper.LogWarning("clickEX",null,l):(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"CI.Warning","FID":"CI","Name":"JSWarning","Text":'+l.message+"}]"}return!0};_w.si_sbwu||(_w.si_sbwu=function(){return!1}),function(){_w._G&&(_G.si_ct_e="click")}();var wlc_d = 1500, wlc_t =63715488079;;var perf;(function(n){function f(n){return i.hasOwnProperty(n)?i[n]:n}function e(n){var t="S";return n==0?t="P":n==2&&(t="M"),t}function o(n){for(var c,i=[],t={},r,l=0;l<n.length;l++){var a=n[l],o=a.v,s=a.t,h=a.k;s===0&&(h=f(h),o=o.toString(36));s===3?i.push(h+":"+o):(r=t[s]=t[s]||[],r.push(h+":"+o))}for(c in t)t.hasOwnProperty(c)&&(r=t[c],i.push(e(+c)+':"'+r.join(",")+'"'));return i.push(u),i}for(var r=["redirectStart","redirectEnd","fetchStart","domainLookupStart","domainLookupEnd","connectStart","secureConnectionStart","connectEnd","requestStart","responseStart","responseEnd","domLoading","domInteractive","domContentLoadedEventStart","domContentLoadedEventEnd","domComplete","loadEventStart","loadEventEnd","unloadEventStart","unloadEventEnd","firstChunkEnd","secondChunkStart","htmlEnd","pageEnd","msFirstPaint"],u="v:1.1",i={},t=0;t<r.length;t++)i[r[t]]=t;n.compress=o})(perf||(perf={}));window.perf=window.perf||{},function(n){n.log=function(t,i){var f=n.compress(t),r;f.push('T:"CI.Perf",FID:"CI",Name:"PerfV2"');var e="/fd/ls/lsp.aspx?",o="sendBeacon",h="<E><T>Event.ClientInst<\/T><IG>"+_G.IG+"<\/IG><TS>"+i+"<\/TS><D><![CDATA[{"+f.join(",")+"}]\]><\/D><\/E>",s="<ClientInstRequest><Events>"+h+"<\/Events><STS>"+i+"<\/STS><\/ClientInstRequest>",u=!_w.navigator||!navigator[o];if(!u)try{navigator[o](e,s)}catch(c){u=!0}u&&(r=sj_gx(),r.open("POST",e,!0),r.setRequestHeader("Content-Type","text/xml"),r.send(s))}}(window.perf);var perf;(function(n){function a(){return c(Math.random()*1e4)}function o(){return y?c(f.now())+l:+new Date}function v(n,r,f){t.length===0&&i&&sb_st(u,1e3);t.push({k:n,v:r,t:f})}function p(n){return i||(r=n),!i}function w(n,t){t||(t=o());v(n,t,0)}function b(n,t){v(n,t,1)}function u(){var u,f;if(t.length){for(u=0;u<t.length;u++)f=t[u],f.t===0&&(f.v-=r);t.push({k:"id",v:e,t:3});n.log(t,o());t=[];i=!0}}function k(){r=o();e=a();i=!1;sj_evt.bind("onP1",u)}var s="performance",h=!!_w[s],f=_w[s],y=h&&!!f.now,c=Math.round,t=[],i=!1,l,r,e;h?l=r=f.timing.navigationStart:r=_w.si_ST?_w.si_ST:+new Date;e=a();n.setStartTime=p;n.mark=w;n.record=b;n.flush=u;n.reset=k;sj_be(window,"load",u,!1);sj_be(window,"beforeunload",u,!1)})(perf||(perf={}));_w.si_PP=function(n,t,i){var r,o,l,h,e,c;if(!_G.PPS){for(o=["FC","BC","SE","TC","H","BP",null];r=o.shift();)o.push('"'+r+'":'+(_G[r+"T"]?_G[r+"T"]-_G.ST:-1));var u=_w.perf,s="navigation",r,f=i||_w.performance&&_w.performance.timing;if(f&&u){if(l=f.navigationStart,u.setStartTime(l),l>=0)for(r in f)h=f[r],typeof h=="number"&&h>0&&r!=="navigationStart"&&r!==s&&u.mark(r,h);u.record("nav",s in f?f[s]:performance[s].type)}e="connection";c="";_w.navigator&&navigator[e]&&(c=',"net":"'+navigator[e].type+'"',navigator[e].downlinkMax&&(c+=',"dlMax":"'+navigator[e].downlinkMax+'"'));_G.PPImg=new Image;_G.PPImg.src=_G.lsUrl+'&Type=Event.CPT&DATA={"pp":{"S":"'+(t||"L")+'",'+o.join(",")+',"CT":'+(n-_G.ST)+',"IL":'+_d.images.length+"}"+(_G.C1?","+_G.C1:"")+c+"}"+(_G.P?"&P="+_G.P:"")+(_G.DA?"&DA="+_G.DA:"")+(_G.MN?"&MN="+_G.MN:"") ...
# //]]></script></head><body onload="if(_w.lb)lb();"><header id="b_header"><form action="/search" id="sb_form"><a class="b_logoArea" h="ID=SERP,5034.1" href="/?FORM=Z9FD1"><h1 aria-label="Go to Bing homepage" class="b_logo" title="Back to Bing search"></h1></a><div class="b_searchboxForm" role="search"><input aria-autocomplete="both" aria-label="Enter your search here - Search suggestions will show as you type" autocapitalize="off" autocomplete="off" autocorrect="off" class="b_searchbox b_softkey" dir="" id="sb_form_q" maxlength="1000" name="q" onfocus="_ge('b_header').className='b_focus';" spellcheck="false" type="search" value="adityachavan198@gmail.com"/><span data-sbtip="Search using an on-screen keyboard" id="vkeyIcon"></span><div data-sbtip="Search the web" id="sb_go_par"><input class="b_searchboxSubmit" id="sb_form_go" name="go" tabindex="0" type="submit" value="Search"/></div><input id="sa_qs" name="qs" type="hidden" value="ds"/><input name="form" type="hidden" value="QBRE"/></div></form><div aria-label="Account Rewards and Preferences" data-priority="2" id="id_h" role="complementary"><a aria-controls="id_d" aria-expanded="false" aria-haspopup="true" class="id_button" data-clarity-mask="true" h="ID=SERP,5035.1" href="javascript:void(0);" id="id_l" role="button"><span aria-hidden="false" id="id_s">Sign in</span><span aria-hidden="false" aria-label="Default Profile Picture" class="sw_spd id_avatar" id="id_a"></span><span aria-hidden="true" id="id_n" style="display:none"></span><img alt="Profile Picture" aria-hidden="true" aria-label="Profile Picture" class="id_avatar sw_spd" data-alt="" data-src="..." id="id_p" onerror="FallBackToDefaultProfilePic(this)" src="..." style="display:none"/></a><span _iid="SERP.5043" id="id_d"></span><a aria-controls="id_hbfo" aria-expanded="false" aria-haspopup="true" aria-label="Settings and quick links" class="idp_ham nohphbtop" h="ID=SERP,5041.1" href="javascript:void(0);" id="id_sc" role="button" tabindex="0"></a><span _iid="SERP.5042" aria-hidden="true" aria-labelledby="id_sc" class="slide_up nohpfo" id="id_hbfo" role="menu"></span></div><nav aria-label="Main menu" class="b_scopebar" role="navigation"><ul class="b_scopehide"><li class="b_active" data-menuurl=""><a h="ID=SERP,5016.1" href="/?scope=web&amp;FORM=HDRSC1">All</a></li><li class="" data-menuurl=""><a h="ID=SERP,5017.1" href="/images/search?q=adityachavan198%40gmail.com&amp;FORM=HDRSC2">Images</a></li><li class="" data-menuurl=""><a h="ID=SERP,5018.1" href="/videos/search?q=adityachavan198%40gmail.com&amp;FORM=HDRSC3">Videos</a></li><li class="" data-menuurl=""><a h="ID=SERP,5019.1" href="/maps?q=adityachavan198%40gmail.com&amp;FORM=HDRSC4">Maps</a></li><li class="" data-menuurl=""><a h="ID=SERP,5020.1" href="/news/search?q=adityachavan198%40gmail.com&amp;FORM=HDRSC6">News</a></li><li class="scopebar_pipe">|</li><li class=" b_nohov" data-menuurl=""><a h="ID=SERP,5021.1" href="/saves?FORM=HDRSAV">My saves</a></li></ul></nav><span class="b_hide langLabel" id="langChange"><a h="ID=SERP,5022.1" href="javascript:void(0);" id="langChangeAnchor"><span id="langLid">English</span><span class="sw_ddbk" id="langChev"></span></a><div class="langD b_dropdown b_hide" id="langDId"><a data-noajax="1" h="ID=SERP,5024.1" href="/search?q=adityachavan198%40gmail.com&amp;setmkt=en-in&amp;setlang=hi-in&amp;sid=1D0BF13BBCA368BB0350FF60BD1C69C2">हिंदी</a><a data-noajax="1" h="ID=SERP,5025.1" href="/search?q=adityachavan198%40gmail.com&amp;setmkt=en-in&amp;setlang=bn-in&amp;sid=1D0BF13BBCA368BB0350FF60BD1C69C2">বাংলা</a><a data-noajax="1" h="ID=SERP,5026.1" href="/search?q=adityachavan198%40gmail.com&amp;setmkt=en-in&amp;setlang=te-in&amp;sid=1D0BF13BBCA368BB0350FF60BD1C69C2">తెలుగు</a><a data-noajax="1" h="ID=SERP,5027.1" href="/search?q=adityachavan198%40gmail.com&amp;setmkt=en-in&amp;setlang=mr-in&amp;sid=1D0BF13BBCA368BB0350FF60BD1C69C2">मराठी</a><a data-noajax="1" h="ID=SERP,5028.1" href="/search?q=adityachavan198%40gmail.com&amp;setmkt=en-in&amp;se ...
# BM.trigger();var Identity; (function(Identity) { Identity.sglid =false; Identity.orgIdPhotoUrl ="https://business.bing.com/api/v3/search/person/photo?id={0}"; })(Identity || (Identity = {}));;var wlc_d =10, wlc_t =63715488079, wlc_wfa =false;;_G.AppVer="8_1_2_6237295";
# //]]></script><script type="text/javascript">//<![CDATA[
# _G.FCT=new Date;
# //]]></script><script type="text/javascript">//<![CDATA[
# _G.BCT=new Date;
# //]]></script><style type="text/css">.ftrH,.ftrHd,.ftrD>a,.ftrD>div{white-space:nowrap;height:36px;line-height:36px;padding:0 16px}.ftrD{max-height:216px;overflow:hidden;min-width:125px}.amazonBackground{background:#f2f2f2 !important}.ftrD>a,.ftrD>div{display:block}.ftrS .ftrD{margin-right:10px}.ftrSbR{position:absolute;top:0;right:0;height:100%;margin:5px 0;padding-right:3px}.ftrB .sw_ddbk{margin:2px 0 2px 7px}.ftrB .sw_tpcg,.ftrB .sw_tpcbl{margin:0 0 0 14px}.ftrH,.ftrHd,.ftrB .sw_ddbk,.ftrB .sw_tpcg,.ftrB .sw_tpcbl{display:inline-block;*display:inline;zoom:1}#b_tween a.ftrH{background:none !important;margin:1px;height:28px;line-height:28px}#b_tween a.ftrH.b_selected{border-style:solid;border-width:1px;border-color:#e5e5e5;border-bottom-color:#fff;margin:0}@media screen and (-ms-high-contrast:active){#b_tween a.ftrH,div.b_dropdown .ftrD a{color:WindowText}}div.b_dropdown .b_selected,#b_tween a.ftrH.b_selected:hover{background:#f2f2f2 !important;border-bottom-color:#f2f2f2}z{a:1}.b_caption.b_snippetgobig p{font-size:18px;line-height:24px !important;color:#111}.b_algo.b_algoBorder{box-shadow:0 0 0 1px rgba(0,0,0,.05),0 2px 3px 0 rgba(0,0,0,.1);border-radius:6px}#b_results>li.b_algoBorder{margin-top:8px;padding-top:15px}a{a:1}.b_vList>li.b_annooverride{padding-bottom:0}a{a:1}ol#b_results li.b_ad{background-color:transparent;border-right:none;border-bottom:1px solid #ebebeb;margin-bottom:1px;padding-right:20px;padding-bottom:5px}ol#b_results li.b_adBottom{border-top:1px solid #ebebeb;border-bottom:0;padding-bottom:0}ol#b_context li.b_ad{background-color:transparent}.sb_add cite{text-transform:lowercase}#b_results .b_ad .sb_adTA .b_caption,#b_results .b_ad .sb_adTA .b_vlist2col li,#b_results .b_ad .sb_adTA .b_factrow,#b_results .b_ad .sb_adTA .b_bcfactrow{padding-bottom:4px}#b_results .b_ad .sb_adTA .b_vlist2col,#b_results .b_ad .sb_adTA .b_factrow,#b_results .b_ad .sb_adTA .b_bcfactrow,#b_results .b_ad .sb_adig{margin-top:0}#b_results .b_ad h3.b_adlabel{margin-bottom:4px}.b_ad .pa_mlo~.sb_adt{margin-bottom:-6px}div#b_content ol#b_results li.b_ad{border-bottom:none}div#b_content ol#b_results li.b_adBottom{border-top:none}#b_results .sb_add h2:hover a{text-decoration:underline}#b_results .sb_add h2:hover{cursor:pointer}.b_ad li.b_adLastChild{margin-bottom:0}#b_results>li.b_ad{background-color:#fcfaf9} #b_context>li.b_ad{background-color:#fcfaf9}.b_ad .b_attribution{text-overflow:ellipsis;overflow:hidden;white-space:nowrap}.b_ad .b_attribution .b_adurl{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;display:inline-block;vertical-align:bottom}.sb_add .hhTitle strong{font-weight:600}.sb_adTA span.ad_sym,.format_sym{font-family:Calibri,'Segoe UI',Arial,Helvetica,sans-serif;line-height:0}.b_adcaret{display:inline-block}.b_adcaret .infobubble_item{display:block;cursor:pointer;margin:2px 14px 0 9px}.b_adcaret .infobubble_item .sw_ddgn{margin:2px -4px 2px -3px;display:block}.b_adcaret_content{text-align:center}.b_adSlug{font-size:11px;font-weight:normal;line-height:14px;border-radius:6px}.b_adSlug{color:#666;border:1px solid #ddd}.sb_adTA .b_adSlug,.ba_results .b_adSlug{color:#666;border:1px solid #ddd}.b_adSlug{padding:2px 4px 2px 4px}.sb_adTA .b_adSlug,.ba_results .b_adSlug{padding:0 2px 0 2px}.b_adSlug{margin-right:4px}.sb_adTA .b_adSlug,.ba_results .b_adSlug{margin-right:4px}#b_results .b_ad .sb_adTA .b_belowcaption{padding-bottom:4px}.sb_pagP_bp:after{-webkit-transform-origin:-1394px 0;transform-origin:-1394px 0}.sb_pagP_bp:hover:after,.sb_pagP_bp:active:after,.sb_pagP_bp:focus:after{-webkit-transform-origin:-1478px 0;transform-origin:-1478px 0}.sb_pagN_bp:after{-webkit-transform-origin:-1394px 0;transform-origin:-1394px 0}.sb_pagN_bp:hover:after,.sb_pagN_bp:active:after,.sb_pagN_bp:focus:after{-webkit-transform-origin:-1478px 0;transform-origin:-1478px 0}.sb_inactP:after,.sb_inactP:hover:after{-webkit-transform-origin:-1562px 0;transform-origin:-1562px 0}.b_pag a{display:block;text-align:center}.b_pag a.sb_bp{min-width:40px ...
# if (typeof DynScopes !== 'undefined') { DynScopes.init("", ""); };var EntityPreviewConfig = { featureList: "", iid: "SERP.5295", testHooks: false };
# //]]></script><script src="/rs/8/2X/cj,nj/4c10930c/19b40d8c.js" type="text/javascript"></script><div id="b_content"><main aria-label="Search Results"><div id="b_tween"><span class="sb_count">9 results</span><span class="ftrB"><a aria-controls="d5072" aria-expanded="false" aria-haspopup="true" aria-label="Filtered by Date" class="ftrH" h="ID=SERP,5226.1" href="javascript:" id="h5072" role="button"><span class="fs_label">Date</span><span class="sw_ddbk"></span> </a></span><span class="ftrB"><a aria-controls="d5067" aria-expanded="false" aria-haspopup="true" aria-label="Filtered by Language" class="ftrH" h="ID=SERP,5235.1" href="javascript:" id="h5067" role="button"><span class="fs_label">Language</span><span class="sw_ddbk"></span> </a></span><span class="ftrB"><a aria-controls="d5068" aria-expanded="false" aria-haspopup="true" aria-label="Filtered by Region" class="ftrH" h="ID=SERP,5239.1" href="javascript:" id="h5068" role="button"><span class="fs_label">Region</span><span class="sw_ddbk"></span> </a></span></div><ol id="b_results"><li class="b_algo"><h2><a h="ID=SERP,5110.1" href="https://github.com/adityachavan198">adityachavan198 (Aditya Chavan) · GitHub</a></h2><div class="b_caption"><div class="b_attribution" u="0|5058|4530305839268949|_J3OWF6dwMYMJU9VGA0Fq6O_0EhFFIAn"><cite>https://<strong>github.com</strong>/adityachavan198</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5111.1"></span></span></div><p>I am a Computer Engineering Student, at the University of Mumbai, currently in my Final year of study. - adityachavan198</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5124.1" href="https://github.com/adityachavan198/Library-app">GitHub - adityachavan198/Library-app: Library Management System</a></h2><div class="b_caption"><div class="b_attribution" u="1|5059|4727294510963570|sezLctWgWEtlueQv0Mss174N4aNv0Ib5"><cite>https://<strong>github.com</strong>/adityachavan198/Library-app</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5125.1"></span></span></div><p>Join <strong>GitHub</strong> today. <strong>GitHub</strong> is home to over 40 million developers working together to host and review code, manage projects, and build software together.</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5138.1" href="https://github.com/adityachavan198/TLB">GitHub - adityachavan198/TLB: Simulation of Translational Look …</a></h2><div class="b_caption"><div class="b_attribution" u="2|5060|5047630357860346|LcQXNYk3PfP3Zb7ihGlKLN4tX6dPXmsi"><cite>https://<strong>github.com</strong>/adityachavan198/TLB</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5139.1"></span></span></div><p>Join <strong>GitHub</strong> today. <strong>GitHub</strong> is home to over 40 million developers working together to host and review code, manage projects, and build software together.</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5151.1" href="https://github.com/adityachavan198/MoneyMee">adityachavan198/MoneyMee: Personal Finance Management …</a></h2><div class="b_caption"><div class="b_attribution" u="3|5061|4583395932899777|PdiMu3uPYngkSZmKTSXhpXHMN_xvX2hD"><cite>https://<strong>github.com</strong>/adityachavan198/MoneyMee</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5152.1"></span></span></div><p>Personal Finance Management Application. Contribute to adityachavan198/MoneyMee development by creating an account on <strong>GitHub</strong>.</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5165.1" href="https://github.com/adityachavan198/Backtothebox">GitHub - adityachavan198/Backtothebox: 2-D Java Game</a></h2><div class="b_caption"><div class="b_attribution" u="4|5062|4712854838183341|FIlM_rv0zcZfKNetqk3zUVIQPFwlSjE8"><cite>https://<strong>github.com</strong>/adityachavan198/Backtothebox</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5166.1"></span></span></di ...
# (function(n,t){onload=function(){_G.BPT=new Date;n&&n();!_w.sb_ppCPL&&t&&sb_st(function(){t(new Date)},0)}})(_w.onload,_w.si_PP);BM.trigger();loadMultiKeyBoardScript=function(){_w.rms.js({'rms:answers:VisualSystem:MultiLingualKeyboardBundle':'\/rb\/6e\/cj,nj\/08d3f262\/e3eef849.js?bu=A-YH9QfjBw',d:1});};;sa_loader=function(){_w.rms.js({'rms:answers:AutoSuggest:AutoSug':'\/rb\/G\/cj,nj\/74c301ba\/40a5a4d0.js?bu=EkTmAekB7AHvAdQBOZoBsAGzAcsBpwE5Oc4BOYoCtgE',d:1});};;_w.rms.js({'A:0':0},{'A:rms:answers:Shared:BingCore.Bundle':'\/rb\/5f\/cj,nj\/e5310029\/71bae1e3.js?bu=EsAg4CDsH4YgmgWXIIsg7SCZIKogsCDXINsgziDAH8ceyR6yHw'},{'A:rms:answers:BoxModel:Framework':'\/rb\/15\/cj,nj\/1a10eb03\/af615ab8.js?bu=DiovY2l3cmZsb7ABrAEvoQEv'},{'A:1':1},{'A:rms:answers:Identity:BlueIdentityDropdownBootStrap':'\/rs\/2Y\/26\/cj,nj\/3f1e2270\/f8c6dd44.js'},{'A:rms:answers:Identity:BlueIdentityHeader':'\/rs\/2Y\/2m\/cj,nj\/4c7364c5\/40e1b425.js'},{'A:2':2},{'A:rms:answers:Identity:SnrWindowsLiveConnectBootstrap':'\/rs\/2Y\/2D\/cj,nj\/bf587ad6\/f1d86b5a.js'},{'A:rms:answers:OrgId:SsoFrame':'\/rs\/46\/A\/cj,nj\/64cc4a49\/e70a8ff8.js'},{'A:3':3},{'A:rms:answers:Identity:ProfilePicturePostLoader':'\/rs\/2Y\/2K\/cj,nj\/93002ee5\/ce33b6aa.js'},{'A:rms:answers:VisualSystem:LanguageSwitch':'\/rb\/6e\/cj,nj\/57013c47\/1adb5dba.js?bu=AvMG6QY'},{'A:4':4},{'A:rms:answers:SegmentFilters:DropDown':'\/rs\/56\/2O\/cj,nj\/4df0cf24\/0120f753.js'},{'A:5':5},{'A:rms:answers:WebResult:WebResultToolbox':'\/rs\/6i\/5o\/cj,nj\/6e795a8b\/1c156e04.js'},{'A:6':6},{'A:rms:answers:Web:SerpKeyboardNavigation_Selector':'\/rs\/6g\/TL\/cj,nj\/1c2f626c\/c9969752.js'},{'A:rms:answers:Web:SerpKeyboardNavigation':'\/rs\/6g\/TS\/cj,nj\/16be2a34\/6323ce42.js'});;
# //]]></script><div id="aRmsDefer"><div style="display:none"><!--//<![CDATA[
# var ErrFuncs;(function(n){function i(n,i,r){t("Error",n,i,r)}function r(n,i,r){t("Warning",n,i,r)}function t(n,t,i,r){var u,f;if(r?(u=r,u.message+=" "+t):u=new Error(t),u.extra="manualError",i&&(u.extra+=" "+i),u.severity=n,f=_w.jsErrorHandler,f)f(u);else throw u;}n.LogError=i;n.LogWarning=r})(ErrFuncs||(ErrFuncs={}));JS={LogError:ErrFuncs.LogError,LogWarning:ErrFuncs.LogWarning};SharedLogHelper={LogError:ErrFuncs.LogError,LogWarning:ErrFuncs.LogWarning,LogFatalError:function(){return null},RegisterErrorFilter:function(){return null}};/*!DisableJavascriptProfiler*/
# 0;var Lib;(function(n){var t;(function(n){function u(n,t){var r,i;if(t==null||n==null)throw new TypeError("Null element passed to Lib.CssClass");if(n.indexOf)return n.indexOf(t);for(r=n.length,i=0;i<r;i++)if(n[i]===t)return i;return-1}function f(n,u){if(n==null)throw new TypeError("Null element passed to Lib.CssClass");if(!t(n,u))if(r&&n.classList)n.classList.add(u);else{var f=i(n)+" "+u;o(n,f)}}function e(n,f){var e,s,h;if(n==null)throw new TypeError("Null element passed to Lib.CssClass");t(n,f)&&(r&&n.classList?n.classList.remove(f):(e=i(n).split(" "),s=u(e,f),s>=0&&e.splice(s,1),h=e.join(" "),o(n,h)))}function s(n,i){if(n==null)throw new TypeError("Null element passed to Lib.CssClass");r&&n.classList?n.classList.toggle(i):t(n,i)?e(n,i):f(n,i)}function t(n,t){var f,e;if(n==null)throw new TypeError("Null element passed to Lib.CssClass");return r&&n.classList?n.classList.contains(t):(f=i(n),f)?(e=f.split(" "),u(e,t)>=0):!1}function h(n,t){var f,e,r,u,o;if(n.getElementsByClassName)return n.getElementsByClassName(t);for(f=n.getElementsByTagName("*"),e=[],r=0;r<f.length;r++)u=f[r],u&&(o=i(u),o&&o.indexOf(t)!==-1&&e.push(u));return e}function o(n,t){n instanceof SVGElement?n.setAttribute("class",t):n.className=t}function i(n){return n instanceof SVGElement?n.getAttribute("class"):n.className}var r=typeof document.body.classList!="undefined";n.add=f;n.remove=e;n.toggle=s;n.contains=t;n.getElementByClassName=h})(t=n.CssClass||(n.CssClass={}))})(Lib||(Lib={}));var MultiLingualKeyboardScriptLoader;(function(n){function u(t,u,f,e,o){n.Languages=t.split(",");n.Languages!==null&&n.Languages.length>0&&(r=n.Languages[0].split(":")[0]);n.EmojiEnabled=f;n.ExtendedKeyboardLayout=e;n.IsSettingsPage=o;n.EmojiEnabled&&sj_evt.bind("onP1",i,!0);n.KeyboardType=u}function i(){typeof MultiLingualKeyBoard=="undefined"||MultiLingualKeyBoard.prevSelectedLang!==r&&MultiLingualKeyBoard.KeyboardTypes.Tabbed!==n.KeyboardType?loadMultiKeyBoardScript():MultiLingualKeyBoard.initializeKeyboard()}function f(){n.KbdIconPressed=!0;e()?MultiLingualKeyBoard.closeKeyboard():i()}function e(){var n=_ge("keyboard");return n!==null&&(n.style.display==="block"||n.style.display==="")?!0:!1}var r="",t;n.EmojiEnabled=!1;n.ExtendedKeyboardLayout=!1;n.IsSettingsPage=!1;n.KbdIconPressed=!1;n.init=u;n.keyboardScriptLoader=i;t=_ge("vkeyIcon");t&&(t.className="vkeyRest",sj_be(t,"click",f))})(MultiLingualKeyboardScriptLoader||(MultiLingualKeyboardScriptLoader={}));MultiLingualKeyboardScriptLoader.init("USX:English (US International)",1, 0, true, false);;var Identity = Identity || {}; (function(i) { i.wlImgSm ="https://storage.live.com/users/0x{0}/myprofile/expressionprofile/profilephoto:UserTileStatic/p?ck=1\u0026ex=720\u0026fofoff=1\u0026sid=1D0BF13BBCA368BB0350FF60BD1C69C2"; i.wlImgLg ="https://storage.live.com/users/0x{0}/myprofile/expressionprofile/profilephoto:UserTileMedium/p?ck=1\u0026ex=720\u0026fofoff=1\u0026sid=1D0BF13BBCA368BB0350FF60BD1C69C2";i.popupLoginUrls = {"WindowsLiveId":"https://login.live.com/login.srf?wa=wsignin1.0\u0026rpsnv=11\u0026ct=1579891280\u0026rver=6.0.5286.0\u0026wp=MBI_SSL\u0026wreply=https:%2F%2fwww.bing.com%2Fsecure%2FPassport.aspx%3Fpopup%3D1%26ssl%3D1\u0026lc=16393\u0026id=264960"}; })(Identity);;var sch=sch||{};(function(){var t=_ge("id_h"),n=_ge("id_sc"),i="click";sj_evt.bind("onP1",function(){setTimeout(function(){t&&n&&(sj_jb("Blue/HamburgerServicesHeaderFlyout_c",0,t,"mouseover",n,i,n,"focus"),sj_be(n,i,function(n){sch.clk=n}))},50)},1)})();var SearchBox;(function(n){function u(){t=_ge("b_header");sj_be(_d.body,"click",i)}function i(n){var i=sj_et(n);i.id!="sb_form_q"&&(t.className=t.className.replace(r,""))}var r=/(^|\s)b_focus(?!\S)/gi,t;n.removeFocusClass=i;sj_evt.bind("onP1",u)})(SearchBox||(SearchBox={}));0;(function(){function i(){var f,e,o,s,h,i;u(window.location.href)||(f=_w.innerWidth,e=sj_cook.get(n,"CW"),(!e||window.sj_b&&e!=sj_b.clientWidth)&&sj_cook.set(n,"CW",f.toString(),!0,"/",null),o=sj_cook.get(n,"CH"),s=sb_de.clientHeight ...
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# (function(){function f(){n()}function e(t){var i=t[0],r=t[1],u=t[2];n()}function o(n){var t=n&&n.length>1&&n[1];t&&u.contains(t,"b_searchbox")&&s()}function s(){Lib.CssClass.add(sj_b,r)}function n(){Lib.CssClass.remove(sj_b,r)}function h(){sj_evt.bind("autosuggestHide",e,!0);sj_evt.bind("focusChange",o,!0);var n=_ge("sb_form");sj_be(n,"submit",f)}function t(){(n(),i)||(i=!0,h())}var i=!1,u=Lib.CssClass,r="as_on";sj_be(_d,"DOMContentLoaded",t);sj_evt.bind("onP1",t,!0);sj_evt.bind("ajax.load",t,!0)})();
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# var wlc=function(n,t,i){var u,f,r;n&&Identity&&(u=Identity.popupLoginUrls)&&(f=u.WindowsLiveId)&&Identity.wlProfile&&(r=_d.createElement("iframe"),r.style.display="none",r.src=f+"&checkda=1",r.setAttribute("data-priority","2"),_d.body.appendChild(r),i&&t&&t("SRCHHPGUSR","WTS",i,1,"/"))};
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# (function() { var config ={"url":"https%3a%2f%2flogin.microsoftonline.com%2fcommon%2foauth2%2fauthorize%3fclient_id%3d9ea1ad79-fdb6-4f9a-8bc3-2b70f96e34c7%26response_type%3did_token%26nonce%3d37b2f774-5f8f-4479-87a3-5f1c34865ebf%26redirect_uri%3dhttps%253a%252f%252fwww.bing.com%252forgid%252fidtoken%252fnosignin%26scope%3dopenid%26response_mode%3dform_post%26msafed%3d0%26prompt%3dnone","sandbox":"allow-forms allow-pointer-lock allow-popups allow-same-origin allow-scripts","currentEpoch":"1579891279000"}; if (false) { if (typeof dbg !== "undefined") { dbg.trace("OrgId", "Delaying SSO on postRBComplete event"); } sj_evt.bind('postRBComplete', function() { setTimeout(function() {_w.rms.js({'rms:answers:OrgId:SsoFrame':'\/rs\/46\/A\/cj,nj\/64cc4a49\/e70a8ff8.js',d:1});sj_evt.fire('ssoFrameExists', config); }, 500); }, true, null, true); } else { sj_evt.fire('ssoFrameExists', config); } })();;
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# sb_ie&&function(){function h(){if(t){var u=n.replace(/www\./i,"");return f&&i(t,r,n+"?PC="+f)||i(t,r,n)||i(t,r,u)||i(t,r,n+"?Form=HPPDH1")||i(t,r,n+"?PC=BNHP")||i(t,r,n+"?PC=BNSR")}return 0}function c(){return i(_w.external,s,n)!=0}function l(){if(u){var n=2*e+o;if(u==n)return!0}return!1}function a(){var n=_ge("hps");return n||(n=sj_ce("span","hps"),n.style.behavior="url(#default#homepage)",sj_b.appendChild(n)),n}function i(n,t,i){try{return n[t](i)}catch(r){return 0}}var s="IsSearchProviderInstalled",r="isHomepage",n="http://"+_d.domain+"/",u=sj_cook.get("_UR","D"),f=sj_cook.get("SRCHS","PC"),t=a(),e=h(),o=c();l()||(u=2*e+o,sj_cook.set("_UR","D",u,1,"/"))}();var sj_appHTML=function(n,t){var f,e,o,i,r,s,h;if(t&&n){var c="innerHTML",l="script",a="appendChild",v="length",y="src",p=sj_ce,u=p("div");if(u[c]="<br>"+t,f=u.childNodes,u.removeChild(f[0]),e=u.getElementsByTagName(l),e)for(o=0;o<e[v];o++)i=p(l),r=e[o],r&&(i.type="text/javascript",s=r.getAttribute(y),s?i.setAttribute(y,s):(i.text=r[c],i.setAttribute("data-bing-script","1")),r.parentNode.replaceChild(i,r));for(h=_d.createDocumentFragment();f[v];)h[a](f[0]);n[a](h)}};var sj_ajax=function(n,t){function h(){i[u]=s;i.abort&&i.abort()}function o(n,t){typeof n=="function"&&n(t,{request:i,appendTo:function(n){i&&sj_appHTML(n,i.responseText)}})}var r,i=sj_gx(),u="onreadystatechange",f,e=null,c=sb_st,l=sb_ct,s=function(){};if(!n||!i){o(r,!1);return}t&&(r=t.callback,f=t.timeout);i.open("get",n,!0);i[u]=function(){if(i.readyState===4){var n=!1;e!==null&&l(e);i.status===200&&(n=!0,i[u]=s);o(r,n)}};sj_evt.bind("ajax.unload",h);i.send();f>0&&(e=c(function(){h();o(r,!1)},f))};
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# (function(){function d(n,t){for(var r=[],i=0;i<t.length;i++)r.push({MonitorID:t[i].name,RequestID:t[i].guid,Result:Math.round(n[i])});return JSON.stringify(r)}function u(){function n(){return Math.floor((1+Math.random())*65536).toString(16).substring(1)}return n()+n()+n()+n()+n()+n()+n()+n()}function h(){return window.performance&&window.performance.getEntriesByName?!0:!1}function c(n,t,i,r,u,f){function l(i){var w,b,p,k,y,g,nt;if(e!=null&&sb_ct(e),s[i]=c!=null?(new Date).getTime()-c:-1,i=(a+v)%n.length,o=new Image,a++<n.length)c=(new Date).getTime(),o.onload=function(){l(i)},w=function(){o.onload=null;o.onerror=null;c=null;l(i)},e=sb_st(function(){w()},t),o.onerror=function(){e!=null&&sb_ct(e);e=null;w()},o.src=n[i];else{if(r!=null&&r.length!==0){if(h())for(y=0;y<n.length;y++)b=n[y],p=window.performance.getEntriesByName(b),s[y]!=-1&&p&&p[0]&&(s[y]=p[0].duration);for(k=d(s,u),y=0;y<r.length;y++)g=r[y],nt=new Image,nt.src=g+k}f!=null&&f()}}var c,e,s=[],v=Math.floor(Math.random()*n.length),a=0,o;sb_st(function(){l(0)},i)}var t=window.location.protocol+"//";if(this.JSON&&t!=="https://"){var n=[u(),u(),u()],f=t+n[0]+".clo.footprintdns.com/apc/",e=t+n[1]+".clo.footprintdns.com/apc/",o=t+n[2]+".clo.footprintdns.com/apc/",i="trans.gif",r=i,s=2e3,l=h(),a=_G.IG,v="&MonitorID=AZR&rid="+a+"&w3c="+l+"&prot="+window.location.protocol+"&v=4&DATA=",y=[t+"fp.msedge.net/r.gif?"+v],p=[f+i,e+i,o+i],w=[f+r+"?"+n[0],e+r+"?"+n[1],o+r+"?"+n[2]],b=[{name:"CLO",guid:n[0]},{name:"CLO",guid:n[1]},{name:"CLO",guid:n[2]}],k=function(){c(w,s,0,y,b,null)};c(p,s,1e3,null,null,k)}})();
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# var ads_choice=function(n){function r(n,t){sj_ajax(t,{callback:function(t,i){if(t){var r=n.parentNode;r.removeChild(n);i.appendTo(r);rms.start();setTimeout(function(){r.getElementsByClassName("infobubble_item")[0].click()},400)}},timeout:5e3})}var i=n.firstChild,t=i.getAttribute("data-id");t&&(t+="&noCacheSeed="+Math.floor(Math.random()*1e4+1),r(i,t))};0;Feedback.Bootstrap.InitializeFeedback({page:true},"sb_feedback",1,0,0);;
# //]]>--></div></div><script type="text/javascript">//<![CDATA[
# _G.HT=new Date;
# //]]></script></body></html>

# %%
soup.find_all("div", class_="b_attribution")
# Out:
# []

# %%
x = 'uzair chhapra'
page = requests.get('https://www.bing.com/search?q='+ x)
soup = BeautifulSoup(page.text)
l = []
for link in soup.find_all('a'):
    l.append(link.get('href'))
l
for i in l:
    if i is not None:
        if i[0] == 'h':
            print(i)
# Out:
# http://go.microsoft.com/fwlink/?LinkId=521839
# http://go.microsoft.com/fwlink/?LinkID=246338
# https://go.microsoft.com/fwlink/?linkid=868922
# https://go.microsoft.com/fwlink/?LinkID=617297

# %%
x = str(soup)

# %%
x.find('<cite>')
# Out:
# 71341

# %%
subscription_key = "5627bd40a3ab44e197a2702915ef9feb"
assert subscription_key

# %%
search_url = "https://api.cognitive.microsoft.com/bing/v7.0/search"

# %%
search_term = "8779238410"

# %%
import requests

headers = {"Ocp-Apim-Subscription-Key": subscription_key}
params = {"q": search_term, "textDecorations": True, "textFormat": "HTML"}
response = requests.get(search_url, headers=headers, params=params)
response.raise_for_status()
search_results = response.json()

# %%
search_results
# Out:
# {'_type': 'SearchResponse',
#  'queryContext': {'originalQuery': '8779238410', 'askUserForLocation': True},
#  'webPages': {'webSearchUrl': 'https://www.bing.com/search?q=8779238410',
#   'totalEstimatedMatches': 1,
#   'value': [{'id': 'https://api.cognitive.microsoft.com/api/v7/#WebPages.0',
#     'name': '877-923-#### (Toll Free, North America) - Easy Phone Number Lookups',
#     'url': 'https://www.easyphonenumberlookups.com/877-923',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.easyphonenumberlookups.com/877-923',
#     'snippet': 'Enter a 10-digit Phone Number. Full report includes available information on owner&#39;s full name, current address, current location, family members, address history, phone type and phone carrier.',
#     'dateLastCrawled': '2020-01-20T16:49:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False}]},
#  'rankingResponse': {'mainline': {'items': [{'answerType': 'WebPages',
#      'resultIndex': 0,
#      'value': {'id': 'https://api.cognitive.microsoft.com/api/v7/#WebPages.0'}}]}}}

# %%
from IPython.display import HTML

rows = "\n".join(["""<tr>
                       <td><a href=\"{0}\">{1}</a></td>
                       <td>{2}</td>
                     </tr>""".format(v["url"], v["name"], v["snippet"])
                  for v in search_results["webPages"]["value"]])
HTML("<table>{0}</table>".format(rows))
# Out:
# <table><tr>
#                        <td><a href="https://www.easyphonenumberlookups.com/877-923">877-923-#### (Toll Free, North America) - Easy Phone Number Lookups</a></td>
#                        <td>Enter a 10-digit Phone Number. Full report includes available information on owner&#39;s full name, current address, current location, family members, address history, phone type and phone carrier.</td>
#                      </tr></table>

# %%
import requests, json

# %%
BASE_URI = 'https://api.cognitive.microsoft.com/bing/v7.0/images/visualsearch'
SUBSCRIPTION_KEY = '5627bd40a3ab44e197a2702915ef9feb'
imagePath = '/Users/adityachavan/Downloads/29c20948-bacc-40df-84f0-102319203b53.JPG'

# %%
HEADERS = {'Ocp-Apim-Subscription-Key': SUBSCRIPTION_KEY}

# %%
file = {'image' : ('myfile', open(imagePath, 'rb'))}

# %%
def print_json(obj):
    """Print the object as json"""
    print(json.dumps(obj, sort_keys=True, indent=2, separators=(',', ': ')))

# %%
try:
    response = requests.post(BASE_URI, headers=HEADERS, files=file)
    response.raise_for_status()
    print_json(response.json())

except Exception as ex:
    raise ex
# Out:
# {
#   "_type": "ImageKnowledge",
#   "image": {
#     "imageInsightsToken": "bcid_S0J0s1VEeOIANA*ccid_QnSzVUR4"
#   },
#   "instrumentation": {
#     "_type": "ResponseInstrumentation"
#   },
#   "tags": [
#     {
#       "actions": [
#         {
#           "_type": "ImageModuleAction",
#           "actionType": "PagesIncluding",
#           "data": {
#             "value": []
#           }
#         },
#         {
#           "actionType": "MoreSizes",
#           "image": {
#             "contentSize": "86211 B",
#             "encodingFormat": "jpeg",
#             "height": 1024,
#             "hostPageDisplayUrl": "",
#             "isFamilyFriendly": true,
#             "name": "",
#             "thumbnail": {
#               "height": 0,
#               "width": 0
#             },
#             "visualWords": "7bfc1 8e4ce f2d40 d8f30 0ea24 d7b64 8f7e6 9a37d d4fc4 56d98 c5b36 8605c 8b010 ce96b 8f81b 9a2d4 603c2 7d5aa d7935 8c467 06813982404681f87f4738bccaeb3000df7a5a8738b0f44d42506c311ce4aedb960989996a8d0d1a9c245c4f7ba0c9e3fc56",
#             "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO",
#             "width": 576
#           }
#         },
#         {
#           "_type": "ImageModuleAction",
#           "actionType": "VisualSearch",
#           "data": {
#             "currentOffset": 0,
#             "nextOffset": 120,
#             "totalEstimatedMatches": 930,
#             "value": [
#               {
#                 "accentColor": "996732",
#                 "contentSize": "83215 B",
#                 "contentUrl": "https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=221048094709231",
#                 "datePublished": "2019-10-19T04:45:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 960,
#                 "hostPageDisplayUrl": "https://www.facebook.com/Neeraj-Kadela-221048094709231",
#                 "hostPageDomainFriendlyName": "Facebook",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.I0PseKBMbqnYCAY0XTH9eA&pid=Api",
#                 "hostPageUrl": "https://www.facebook.com/Neeraj-Kadela-221048094709231/",
#                 "imageId": "1644DC7FA72B784CC9379EED9E09456D417398A7",
#                 "imageInsightsToken": "ccid_EcCnuJdB*mid_1644DC7FA72B784CC9379EED9E09456D417398A7*simid_608012449119863493*thid_OIP.EcCnuJdBc9xG4WgKdgmhBAHaJ4",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Neeraj Kadela - Home | Facebook",
#                 "thumbnail": {
#                   "height": 632,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.EcCnuJdBc9xG4WgKdgmhBAHaJ4&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1644DC7FA72B784CC9379EED9E09456D417398A7&simid=608012449119863493",
#                 "width": 720
#               },
#               {
#                 "accentColor": "684838",
#                 "contentSize": "27459 B",
#                 "contentUrl": "http://www.riyadcapital.com/en/Images/Online_tcm10-4610.jpg",
#                 "datePublished": "2014-12-18T17:09:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 320,
#                 "hostPageDisplayUrl": "www.riyadcapital.com/en/information/ways-to-invest/online",
#                 "hostPageUrl": "http://www.riyadcapital.com/en/information/ways-to-invest/online",
#                 "imageId": "1CC0DA73678FD43C4C943B453DD8A48C17735ACB",
#                 "imageInsightsToken": "ccid_41VxAdNB*mid_1CC0DA73678FD43C4C943B453DD8A48C17735ACB*simid_608023637446625146*thid_OIP.41VxAdNBXKR2SJdVoLiFcwHaEK",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 5,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Riyad Capital Online | Ways To Invest | Riyad Capital",
#                 "thumbnail": {
#                   "height": 266,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse4.mm.bing.net/th?id=OIP.41VxAdNBXKR2SJdVoLiFcwHaEK&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1CC0DA73678FD43C4C943B453DD8A48C17735ACB&simid=608023637446625146",
#                 "width": 570
#               },
#               {
#                 "accentColor": "A74824",
#                 "contentSize": "38027 B",
#                 "contentUrl": "https://thumbs.dreamstime.com/b/hipster-bathrobe-surprised-face-secretly-listen-conversation-secret-spy-concept-man-beard-mustache-eavesdrops-using-118327803.jpg",
#                 "datePublished": "2019-07-31T00:50:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 900,
#                 "hostPageDisplayUrl": "https://www.dreamstime.com/royalty-free-stock-images-surprised-spy-image12871389",
#                 "hostPageDomainFriendlyName": "Dreamstime",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.9TlIIBgEFhmYI3Rtyk2IKA&pid=Api",
#                 "hostPageUrl": "https://www.dreamstime.com/royalty-free-stock-images-surprised-spy-image12871389",
#                 "imageId": "D498DB91D6AB07C5744C8187D4292C92EFE38138",
#                 "imageInsightsToken": "ccid_qa5MTTwv*mid_D498DB91D6AB07C5744C8187D4292C92EFE38138*simid_608047586212513588*thid_OIP.qa5MTTwvDsn1yz-QTVbUagHaLw",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Surprised Spy stock image. Image of closeup, woman, security - 12871389",
#                 "thumbnail": {
#                   "height": 752,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.qa5MTTwvDsn1yz-QTVbUagHaLw&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=D498DB91D6AB07C5744C8187D4292C92EFE38138&simid=608047586212513588",
#                 "width": 567
#               },
#               {
#                 "accentColor": "2C4D5F",
#                 "contentSize": "27380 B",
#                 "contentUrl": "https://www.hillcitybride.com/wp-content/uploads/2011/01/ashleymatt-61.jpg",
#                 "datePublished": "2019-10-15T21:53:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 390,
#                 "hostPageDisplayUrl": "https://www.hillcitybride.com/2011/02/everyday-e-session-by-jane-bradley-photography...",
#                 "hostPageUrl": "https://www.hillcitybride.com/2011/02/everyday-e-session-by-jane-bradley-photography-matt-ashley/",
#                 "imageId": "7E5EF79E54973815CBB0A6C1EFCB63CCBA7AE14A",
#                 "imageInsightsToken": "ccid_WaFUDhUm*mid_7E5EF79E54973815CBB0A6C1EFCB63CCBA7AE14A*simid_608041049265735371*thid_OIP.WaFUDhUmovzKI3r3Owch3gAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Everyday E-Session \u2013 Matt & Ashley \u00bb Hill City Bride | Virginia Wedding ...",
#                 "thumbnail": {
#                   "height": 390,
#                   "width": 260
#                 },
#                 "thumbnailUrl": "https://tse4.mm.bing.net/th?id=OIP.WaFUDhUmovzKI3r3Owch3gAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=7E5EF79E54973815CBB0A6C1EFCB63CCBA7AE14A&simid=608041049265735371",
#                 "width": 260
#               },
#               {
#                 "accentColor": "586873",
#                 "contentSize": "28235 B",
#                 "contentUrl": "https://freestudyadvisor.com/wp-content/uploads/2019/08/20-Businesses-You-can-start-without-leaving-your-Job.jpg",
#                 "datePublished": "2019-12-20T17:57:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 374,
#                 "hostPageDisplayUrl": "https://freestudyadvisor.com/20-businesses-you-can-start-without-leaving-your-job",
#                 "hostPageUrl": "https://freestudyadvisor.com/20-businesses-you-can-start-without-leaving-your-job/",
#                 "imageId": "096D151D49042543BBF076BAAEB9E19C70A35BE4",
#                 "imageInsightsToken": "ccid_BNU0hreH*mid_096D151D49042543BBF076BAAEB9E19C70A35BE4*simid_608046830282212484*thid_OIP.BNU0hreHSvkLaVrPpiSRRQHaD-",
#                 "insightsMetadata": {
#                   "availableSizesCount": 2,
#                   "pagesIncludingCount": 4
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "20 Businesses You can start without leaving your Job",
#                 "thumbnail": {
#                   "height": 254,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.BNU0hreHSvkLaVrPpiSRRQHaD-&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=096D151D49042543BBF076BAAEB9E19C70A35BE4&simid=608046830282212484",
#                 "width": 697
#               },
#               {
#                 "accentColor": "284971",
#                 "contentSize": "295340 B",
#                 "contentUrl": "https://format-com-cld-res.cloudinary.com/image/private/s--Dvv5b-lg--/c_crop,h_699,w_699,x_175,y_0/c_fill,g_center,h_1200,w_1600/a_auto,fl_keep_iptc.progressive,q_95/v1/fce55c4773ae86ce845f9cff9ad605f8/RG-16FEB16-360_JPG.jpg",
#                 "datePublished": "2018-10-08T02:38:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1200,
#                 "hostPageDisplayUrl": "www.gerszak.com/3156336-assignments",
#                 "hostPageUrl": "http://www.gerszak.com/3156336-assignments",
#                 "imageId": "AAD40788FF946FD81EE1C91FAD202FB6781CEDD7",
#                 "imageInsightsToken": "ccid_Pmfc12uz*mid_AAD40788FF946FD81EE1C91FAD202FB6781CEDD7*simid_608017641686568507*thid_OIP.Pmfc12uz5X7Ns0MExErAqAHaFj",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Assignments - Rafal Gerszak",
#                 "thumbnail": {
#                   "height": 355,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.Pmfc12uz5X7Ns0MExErAqAHaFj&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=AAD40788FF946FD81EE1C91FAD202FB6781CEDD7&simid=608017641686568507",
#                 "width": 1600
#               },
#               {
#                 "accentColor": "6A616A",
#                 "contentSize": "323829 B",
#                 "contentUrl": "https://premierhealthsolutions.com/wp-content/uploads/2015/06/Home-06-1000x500.jpg",
#                 "datePublished": "2019-11-08T19:44:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 500,
#                 "hostPageDisplayUrl": "https://premierhealthsolutions.com/our-services",
#                 "hostPageUrl": "https://premierhealthsolutions.com/our-services/",
#                 "imageId": "964F93B04C343BB1E8463263EC264F2A4C976E28",
#                 "imageInsightsToken": "ccid_Bf3iuCDP*mid_964F93B04C343BB1E8463263EC264F2A4C976E28*simid_608036230357713551*thid_OIP.Bf3iuCDPmYRNsDaN-jAJxQHaDt",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Our Services | Premier Health Solutions, LLC",
#                 "thumbnail": {
#                   "height": 237,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.Bf3iuCDPmYRNsDaN-jAJxQHaDt&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=964F93B04C343BB1E8463263EC264F2A4C976E28&simid=608036230357713551",
#                 "width": 1000
#               },
#               {
#                 "accentColor": "3D8E80",
#                 "contentSize": "36892 B",
#                 "contentUrl": "http://img5.bdbphotos.com/images/orig/y/t/ytqawiuzh2qaqtwq.jpg?kj8as6ye",
#                 "datePublished": "2001-01-01T00:00:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 681,
#                 "hostPageDisplayUrl": "fanpix.famousfix.com/gallery/marcello-thedford-pictures.htm",
#                 "hostPageUrl": "http://fanpix.famousfix.com/gallery/marcello-thedford-pictures.htm",
#                 "imageId": "02C8813681A106FD6D3428573861BCB7DFE234A1",
#                 "imageInsightsToken": "ccid_Yd9G0ov/*mid_02C8813681A106FD6D3428573861BCB7DFE234A1*simid_608049338543572615*thid_OIP.Yd9G0ov!_zW-ijQsjvuPgMwAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Marcello Thedford Pictures - Marcello Thedford Photo Gallery - 2015",
#                 "thumbnail": {
#                   "height": 681,
#                   "width": 454
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.Yd9G0ov_zW-ijQsjvuPgMwAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=02C8813681A106FD6D3428573861BCB7DFE234A1&simid=608049338543572615",
#                 "width": 454
#               },
#               {
#                 "accentColor": "A46E27",
#                 "contentSize": "48197 B",
#                 "contentUrl": "https://blaqer.com/wp-content/uploads/2019/01/ernest-grant_1200xx4264-2399-0-506-1000x600.jpg",
#                 "datePublished": "2019-12-13T21:48:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 600,
#                 "hostPageDisplayUrl": "https://blaqer.com/first-black-man-elected-president-of-the-american-nurses-association...",
#                 "hostPageUrl": "https://blaqer.com/first-black-man-elected-president-of-the-american-nurses-association-ana/",
#                 "imageId": "49A25D8EA1FD0DC642F1F66EA67FCD21974A2A0E",
#                 "imageInsightsToken": "ccid_3agus+mL*mid_49A25D8EA1FD0DC642F1F66EA67FCD21974A2A0E*simid_608051159605118215*thid_OIP.3agus-mLkaypwPTitVvUTQHaEc",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "First Black Man Elected President of the American Nurses Association ...",
#                 "thumbnail": {
#                   "height": 284,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.3agus-mLkaypwPTitVvUTQHaEc&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=49A25D8EA1FD0DC642F1F66EA67FCD21974A2A0E&simid=608051159605118215",
#                 "width": 1000
#               },
#               {
#                 "accentColor": "904A3B",
#                 "contentSize": "722263 B",
#                 "contentUrl": "http://i.imgur.com/GlF1Jfl.jpg",
#                 "datePublished": "2019-04-16T22:44:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1200,
#                 "hostPageDisplayUrl": "dailyexo.tumblr.com/post/141832914035/suho-160327-glory-day-stage-greeting-credit",
#                 "hostPageDomainFriendlyName": "Tumblr",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.hDFPAeh8tla6XzgtIthRNA&pid=Api",
#                 "hostPageUrl": "http://dailyexo.tumblr.com/post/141832914035/suho-160327-glory-day-stage-greeting-credit",
#                 "imageId": "6C54665B9BB3D1E95663A6310FE730771BE2019F",
#                 "imageInsightsToken": "ccid_ReZX9mBY*mid_6C54665B9BB3D1E95663A6310FE730771BE2019F*simid_608040959067622813*thid_OIP.ReZX9mBYyWnOYnTkaElZ6gHaE8",
#                 "insightsMetadata": {
#                   "availableSizesCount": 2,
#                   "pagesIncludingCount": 3
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "DAILYEXO",
#                 "thumbnail": {
#                   "height": 316,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP.ReZX9mBYyWnOYnTkaElZ6gHaE8&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=6C54665B9BB3D1E95663A6310FE730771BE2019F&simid=608040959067622813",
#                 "width": 1800
#               },
#               {
#                 "accentColor": "845947",
#                 "contentSize": "4065529 B",
#                 "contentUrl": "http://tlmagazine.com/wp-content/uploads/2016/12/6-maquette_kiki_1_hr.jpg",
#                 "datePublished": "2016-12-30T03:29:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 3508,
#                 "hostPageDisplayUrl": "tlmagazine.com/kiki-van-eijk-free-spirit",
#                 "hostPageUrl": "http://tlmagazine.com/kiki-van-eijk-free-spirit/",
#                 "imageId": "779E4ED6F04885864D1E83F6E35FA2CB90ED7D89",
#                 "imageInsightsToken": "ccid_H099pFGD*mid_779E4ED6F04885864D1E83F6E35FA2CB90ED7D89*simid_607989157474271535*thid_OIP.H099pFGD7KZs-RC-j1by3wHaKe",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Kiki van Eijk: Free Spirit \u2013 TLmagazine",
#                 "thumbnail": {
#                   "height": 670,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP.H099pFGD7KZs-RC-j1by3wHaKe&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=779E4ED6F04885864D1E83F6E35FA2CB90ED7D89&simid=607989157474271535",
#                 "width": 2480
#               },
#               {
#                 "accentColor": "8D533E",
#                 "contentSize": "18630 B",
#                 "contentUrl": "https://drsummerschiropractic.com/media/male-neck-adjustment.jpg",
#                 "datePublished": "2019-09-18T13:14:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 281,
#                 "hostPageDisplayUrl": "https://drsummerschiropractic.com",
#                 "hostPageUrl": "https://drsummerschiropractic.com/",
#                 "imageId": "1790B8722A1464F8A6A6A727696C9B2E0719FEB0",
#                 "imageInsightsToken": "ccid_kbWwBbt6*mid_1790B8722A1464F8A6A6A727696C9B2E0719FEB0*simid_608036913271017205*thid_OIP.kbWwBbt6crZzpJ2YLtg--wAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Sports Medicine Chiropractors \u2013 New Milford, PA \u2013 Chiropractic Health ...",
#                 "thumbnail": {
#                   "height": 281,
#                   "width": 468
#                 },
#                 "thumbnailUrl": "https://tse4.mm.bing.net/th?id=OIP.kbWwBbt6crZzpJ2YLtg--wAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1790B8722A1464F8A6A6A727696C9B2E0719FEB0&simid=608036913271017205",
#                 "width": 468
#               },
#               {
#                 "accentColor": "911413",
#                 "contentSize": "40215 B",
#                 "contentUrl": "http://1.bp.blogspot.com/-2Kg8rXSPqzk/Te4a8CXkDNI/AAAAAAAA38o/L6qKi7qRu6g/s600/20101113_jgs_mgy_2.jpg",
#                 "datePublished": "2018-10-22T06:53:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 600,
#                 "hostPageDisplayUrl": "mancentral1.blogspot.com/2011/07/azfar-rehman-pakistani-actor.html",
#                 "hostPageDomainFriendlyName": "blogspot.com",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.kCKFU1-d0l3Elu2Vvbpmew&pid=Api",
#                 "hostPageUrl": "http://mancentral1.blogspot.com/2011/07/azfar-rehman-pakistani-actor.html",
#                 "imageId": "A76E11BC55516EF0D5BFBAA08EEC0D61B2888B8B",
#                 "imageInsightsToken": "ccid_fCsPtoRi*mid_A76E11BC55516EF0D5BFBAA08EEC0D61B2888B8B*simid_608024419131130379*thid_OIP.fCsPtoRirxXIXgpIfnjDUQAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 6,
#                   "pagesIncludingCount": 5,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Man Central: Azfar Rehman: Pakistani Actor",
#                 "thumbnail": {
#                   "height": 600,
#                   "width": 404
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.fCsPtoRirxXIXgpIfnjDUQAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A76E11BC55516EF0D5BFBAA08EEC0D61B2888B8B&simid=608024419131130379",
#                 "width": 404
#               },
#               {
#                 "accentColor": "82A328",
#                 "contentSize": "109550 B",
#                 "contentUrl": "https://thumbs.dreamstime.com/z/mature-couple-hugging-garden-doors-29592776.jpg",
#                 "datePublished": "2017-12-24T03:33:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 957,
#                 "hostPageDisplayUrl": "dreamstime.com/royalty-free-stock-image-mature-couple-hugging-garden-doors-image29592776",
#                 "hostPageDomainFriendlyName": "Dreamstime",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.9TlIIBgEFhmYI3Rtyk2IKA&pid=Api",
#                 "hostPageUrl": "http://dreamstime.com/royalty-free-stock-image-mature-couple-hugging-garden-doors-image29592776",
#                 "imageId": "A4123641BE24CB89799AE9D51EF058555C9FE999",
#                 "imageInsightsToken": "ccid_tTDjIaIH*mid_A4123641BE24CB89799AE9D51EF058555C9FE999*simid_608035671998139336*thid_OIP.tTDjIaIHAim6lERHEpt!_zwHaFc",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 4,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Mature Couple Hugging By Garden Doors. Stock Photo - Image: 29592776",
#                 "thumbnail": {
#                   "height": 348,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.tTDjIaIHAim6lERHEpt_zwHaFc&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A4123641BE24CB89799AE9D51EF058555C9FE999&simid=608035671998139336",
#                 "width": 1300
#               },
#               {
#                 "accentColor": "8C5F3F",
#                 "contentSize": "26481 B",
#                 "contentUrl": "http://ak2.picdn.net/shutterstock/videos/19066432/thumb/1.jpg?i10c=img.resize(height:160)",
#                 "datePublished": "2018-01-30T23:56:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 480,
#                 "hostPageDisplayUrl": "www.shutterstock.com/video/search/woman-gynecologist",
#                 "hostPageDomainFriendlyName": "Shutterstock",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.rI8vVCg0IUeWpoY9HDLoDw&pid=Api",
#                 "hostPageUrl": "http://www.shutterstock.com/video/search/woman-gynecologist",
#                 "imageId": "B1DF1EAD203C13325531A8CEB9E70051F3A97F3D",
#                 "imageInsightsToken": "ccid_w4G/igQ1*mid_B1DF1EAD203C13325531A8CEB9E70051F3A97F3D*simid_608001303623765360*thid_OIP.w4G!_igQ1whvjOZ02cZYyZgHaEL",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Woman Gynecologist Stock Footage Video | Shutterstock",
#                 "thumbnail": {
#                   "height": 267,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.w4G_igQ1whvjOZ02cZYyZgHaEL&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=B1DF1EAD203C13325531A8CEB9E70051F3A97F3D&simid=608001303623765360",
#                 "width": 852
#               },
#               {
#                 "accentColor": "A92B22",
#                 "contentSize": "118626 B",
#                 "contentUrl": "https://lh3.googleusercontent.com/-rJtajGQCRN0/UqTrMgRO7-I/AAAAAAAAA3c/dsZVyFDm4MA/w530-h788-n/Syed%2BMeer%2BFazal%2BAnjum%2BHashmi%2B-%2B1",
#                 "datePublished": "2019-02-18T11:49:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 788,
#                 "hostPageDisplayUrl": "https://plus.google.com/106248518471992691503",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.SkeIwd_DlrH4Y1WydMwmsw&pid=Api",
#                 "hostPageUrl": "https://plus.google.com/106248518471992691503",
#                 "imageId": "1292834BE87E12AAA42DA11C51AFD243088CACA0",
#                 "imageInsightsToken": "ccid_w0uy4PA+*mid_1292834BE87E12AAA42DA11C51AFD243088CACA0*simid_608050356448922477*thid_OIP.w0uy4PA-ZSzO01nkpgGd8AHaLA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Syed Meer Fazal Anjum Hashmi - Google+",
#                 "thumbnail": {
#                   "height": 704,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.w0uy4PA-ZSzO01nkpgGd8AHaLA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1292834BE87E12AAA42DA11C51AFD243088CACA0&simid=608050356448922477",
#                 "width": 530
#               },
#               {
#                 "accentColor": "865A45",
#                 "contentSize": "415968 B",
#                 "contentUrl": "http://media.architecturaldigest.com/photos/58caaa18cc2d6739d52d55a4/master/pass/Delfina-01-Delfina-1.jpg",
#                 "datePublished": "2017-03-16T19:50:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 3450,
#                 "hostPageDisplayUrl": "www.architecturaldigest.com/gallery/delfina-delettrez-fendis-favorite-things",
#                 "hostPageDomainFriendlyName": "Architectural Digest",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.PBsJywMH5i6RjC-9IyWfag&pid=Api",
#                 "hostPageUrl": "http://www.architecturaldigest.com/gallery/delfina-delettrez-fendis-favorite-things",
#                 "imageId": "BD07C5443F71E4C1787ECCBCF7956F6DD4B23B42",
#                 "imageInsightsToken": "ccid_Gt3pGtbT*mid_BD07C5443F71E4C1787ECCBCF7956F6DD4B23B42*simid_608015026070948524*thid_OIP.Gt3pGtbTwnrovIwkAct13QHaLH",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Delfina Delettrez Fendi\u2019s Favorite Things Photos | Architectural Digest",
#                 "thumbnail": {
#                   "height": 711,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP.Gt3pGtbTwnrovIwkAct13QHaLH&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=BD07C5443F71E4C1787ECCBCF7956F6DD4B23B42&simid=608015026070948524",
#                 "width": 2300
#               },
#               {
#                 "accentColor": "684536",
#                 "contentSize": "68630 B",
#                 "contentUrl": "http://1.bp.blogspot.com/-Tu_XQLTi82E/UGTZ21cnQkI/AAAAAAAAO4M/i-_Rg2Fnl5E/s1600/1.jpg",
#                 "datePublished": "2019-10-25T20:44:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 498,
#                 "hostPageDisplayUrl": "www.dbsknights.net/2012/09/photos-120928-tvxq-staff-diary-update.html",
#                 "hostPageUrl": "http://www.dbsknights.net/2012/09/photos-120928-tvxq-staff-diary-update.html",
#                 "imageId": "665DA16160E56514B6CF0473E20580D990BEA372",
#                 "imageInsightsToken": "ccid_sOSI+klr*mid_665DA16160E56514B6CF0473E20580D990BEA372*simid_607992460303598926*thid_OIP.sOSI-klrUAdEZWykxUJADQAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 4,
#                   "pagesIncludingCount": 5
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "[PHOTOS] 120928 TVXQ - Staff Diary Update | DBSK Sleepless Nights (TVXQ ...",
#                 "thumbnail": {
#                   "height": 498,
#                   "width": 333
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.sOSI-klrUAdEZWykxUJADQAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=665DA16160E56514B6CF0473E20580D990BEA372&simid=607992460303598926",
#                 "width": 333
#               },
#               {
#                 "accentColor": "835848",
#                 "contentSize": "496600 B",
#                 "contentUrl": "https://www.aopa.org/-/media/images/aopa-main/go-fly/medical/airman-medical-certification/selfground.jpg?la=en&hash=CFADEA9D8A71B25CB24B5F267B623FC0A7BE9833",
#                 "datePublished": "2019-10-08T12:07:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 2160,
#                 "hostPageDisplayUrl": "https://www.aopa.org/go-fly/medical-resources/airman-medical-certification",
#                 "hostPageDomainFriendlyName": "AOPA",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.hUUZvVp6PFpaT4TMmahJKQ&pid=Api",
#                 "hostPageUrl": "https://www.aopa.org/go-fly/medical-resources/airman-medical-certification",
#                 "imageId": "0151FF6E1E1F9CCC1D2C4BBA50F509137A9B825B",
#                 "imageInsightsToken": "ccid_JBFr7Npx*mid_0151FF6E1E1F9CCC1D2C4BBA50F509137A9B825B*simid_608040645547459625*thid_OIP.JBFr7NpxiEiT-hdco9aqewHaEK",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Airman Medical Certfication - AOPA",
#                 "thumbnail": {
#                   "height": 266,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.JBFr7NpxiEiT-hdco9aqewHaEK&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=0151FF6E1E1F9CCC1D2C4BBA50F509137A9B825B&simid=608040645547459625",
#                 "width": 3840
#               },
#               {
#                 "accentColor": "505157",
#                 "contentSize": "49512 B",
#                 "contentUrl": "https://scallyguy.com/wp-content/uploads/2017/07/mormonboyz_elder_garrett_chapter3_hi-res.7_12-07-2017-1024x683.jpg",
#                 "datePublished": "2019-11-01T03:25:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 683,
#                 "hostPageDisplayUrl": "https://scallyguy.com/2017/07/mormonboyz-elder-garrett-initiation",
#                 "hostPageUrl": "https://scallyguy.com/2017/07/mormonboyz-elder-garrett-initiation/",
#                 "imageId": "CC3B834FC7824847DBE44086F0A9519AA9A0D60E",
#                 "imageInsightsToken": "ccid_/fu5T+89*mid_CC3B834FC7824847DBE44086F0A9519AA9A0D60E*simid_608042389294810974*thid_OIP.!_fu5T-89iBllXH-ER-PA3wHaE8",
#                 "insightsMetadata": {
#                   "availableSizesCount": 2,
#                   "pagesIncludingCount": 3,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "MormonBoyz \u2013 Elder Garrett \u2013 INITIATION | Scallyguy",
#                 "thumbnail": {
#                   "height": 316,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP._fu5T-89iBllXH-ER-PA3wHaE8&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=CC3B834FC7824847DBE44086F0A9519AA9A0D60E&simid=608042389294810974",
#                 "width": 1024
#               },
#               {
#                 "accentColor": "A74D24",
#                 "contentSize": "32537 B",
#                 "contentUrl": "https://drlam-6bmwcfqpiol3wo6jnjj0.netdna-ssl.com/images/main-slide-stress-and-hypertension-2095.jpg",
#                 "datePublished": "2019-06-13T00:50:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 376,
#                 "hostPageDisplayUrl": "https://www.drlam.com/blog/cholesterol-stress-and-hypertension/2095",
#                 "hostPageUrl": "https://www.drlam.com/blog/cholesterol-stress-and-hypertension/2095/",
#                 "imageId": "22FC77474192614A64885D589B1312E6FA5C800F",
#                 "imageInsightsToken": "ccid_qewxhsIh*mid_22FC77474192614A64885D589B1312E6FA5C800F*simid_608045524623755155*thid_OIP.qewxhsIhMQnaC9fMSh5NQwHaEF",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Stress and Hypertension: Spotlight on Related Common Health Issues",
#                 "thumbnail": {
#                   "height": 261,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse4.mm.bing.net/th?id=OIP.qewxhsIhMQnaC9fMSh5NQwHaEF&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=22FC77474192614A64885D589B1312E6FA5C800F&simid=608045524623755155",
#                 "width": 682
#               },
#               {
#                 "accentColor": "394692",
#                 "contentSize": "65012 B",
#                 "contentUrl": "https://i.pinimg.com/736x/f8/ff/e7/f8ffe7485a81b9fb89746f63587804a7--pregnant-wife-reby-sky.jpg",
#                 "datePublished": "2019-05-25T19:42:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 914,
#                 "hostPageDisplayUrl": "https://www.pinterest.com/pin/32932641005281168",
#                 "hostPageDomainFriendlyName": "Pinterest",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.PmATFqOwm9_sUEmusAtcwA&pid=Api",
#                 "hostPageUrl": "https://www.pinterest.com/pin/32932641005281168/",
#                 "imageId": "E1D828A56F6DF4879F55ABD2799DB03F95DF2211",
#                 "imageInsightsToken": "ccid_6eF9Afsn*mid_E1D828A56F6DF4879F55ABD2799DB03F95DF2211*simid_607987125968441306*thid_OIP.6eF9Afsnwd1!_Zf8I0kmgIwHaLA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 2,
#                   "pagesIncludingCount": 8,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Matt Hardy & his pregnant wife Reby Sky #2 | Cute | Reby sky, WWE, Twitter",
#                 "thumbnail": {
#                   "height": 704,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.6eF9Afsnwd1_Zf8I0kmgIwHaLA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=E1D828A56F6DF4879F55ABD2799DB03F95DF2211&simid=607987125968441306",
#                 "width": 615
#               },
#               {
#                 "accentColor": "676F5C",
#                 "contentSize": "16866 B",
#                 "contentUrl": "https://lh3.googleusercontent.com/-boEHcF3n_xc/TYS6ilo4DwI/AAAAAAAAAJY/eZ3vIZawDIQ/s320/Maninthemirror.jpg",
#                 "datePublished": "2011-03-19T12:00:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 320,
#                 "hostPageDisplayUrl": "https://reflectionsonthedance.wordpress.com/2011/03/19/we-are-all-the-man-in-the-mirror...",
#                 "hostPageDomainFriendlyName": "WordPress.com",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.ZTFmdz3IgSe9Ov4Lbf5epw&pid=Api",
#                 "hostPageUrl": "https://reflectionsonthedance.wordpress.com/2011/03/19/we-are-all-the-man-in-the-mirror-make-that-change/",
#                 "imageId": "CD15541C90094C29887A22354320C37267BA5BC9",
#                 "imageInsightsToken": "ccid_FlBev1Vi*mid_CD15541C90094C29887A22354320C37267BA5BC9*simid_607990162494130774*thid_OIP.FlBev1VigZRPYT5jAI2stwDvEs",
#                 "insightsMetadata": {
#                   "availableSizesCount": 7,
#                   "pagesIncludingCount": 10,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "We Are All The Man In The Mirror: Make That Change | Reflections on the ...",
#                 "thumbnail": {
#                   "height": 320,
#                   "width": 255
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP.FlBev1VigZRPYT5jAI2stwDvEs&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=CD15541C90094C29887A22354320C37267BA5BC9&simid=607990162494130774",
#                 "width": 255
#               },
#               {
#                 "accentColor": "774825",
#                 "contentSize": "30808 B",
#                 "contentUrl": "https://i.pinimg.com/736x/b4/ce/90/b4ce9054a4161f6bd0d99f8bcbe94fc1--vampire-dairies-the-vampire-diaries.jpg",
#                 "datePublished": "2001-01-01T00:00:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 800,
#                 "hostPageDisplayUrl": "https://www.pinterest.com/Vampdiaires1234/nina-dobrev",
#                 "hostPageDomainFriendlyName": "Pinterest",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.PmATFqOwm9_sUEmusAtcwA&pid=Api",
#                 "hostPageUrl": "https://www.pinterest.com/Vampdiaires1234/nina-dobrev/",
#                 "imageId": "66770655F775372382E807929692670280AAFE57",
#                 "imageInsightsToken": "ccid_MrvRTh3e*mid_66770655F775372382E807929692670280AAFE57*simid_608011323810319941*thid_OIP.MrvRTh3eODGJ0EPuA6HBaAHaOE",
#                 "insightsMetadata": {
#                   "availableSizesCount": 4,
#                   "pagesIncludingCount": 20,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "126 best Nina Dobrev images on Pinterest | Nina dobrev, The vampire ...",
#                 "thumbnail": {
#                   "height": 900,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.MrvRTh3eODGJ0EPuA6HBaAHaOE&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=66770655F775372382E807929692670280AAFE57&simid=608011323810319941",
#                 "width": 421
#               },
#               {
#                 "accentColor": "A54226",
#                 "contentSize": "44798 B",
#                 "contentUrl": "https://pbs.twimg.com/media/Cg2sHSVWkAUW4UJ.jpg",
#                 "datePublished": "2017-11-20T22:57:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 667,
#                 "hostPageDisplayUrl": "https://twitter.com/kwoojae/status/724424374229581824",
#                 "hostPageDomainFriendlyName": "Twitter",
#                 "hostPageUrl": "https://twitter.com/kwoojae/status/724424374229581824",
#                 "imageId": "1F4D66A9F6F480CF0D44985ABBF2DAE38C1862D7",
#                 "imageInsightsToken": "ccid_KbPUm37j*mid_1F4D66A9F6F480CF0D44985ABBF2DAE38C1862D7*simid_608014257301553654*thid_OIP.KbPUm37js904ua85s3XmxAHaJ4",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1,
#                   "recipeSourcesCount": 0
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "dani \ud83c\udf39 on Twitter: \"#ASTRO Kim Myung Jun Vocalist Bday: 5 March, 1994 ...",
#                 "thumbnail": {
#                   "height": 632,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.KbPUm37js904ua85s3XmxAHaJ4&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1F4D66A9F6F480CF0D44985ABBF2DAE38C1862D7&simid=608014257301553654",
#                 "width": 500
#               },
#               {
#                 "accentColor": "476D84",
#                 "contentSize": "25520 B",
#                 "contentUrl": "http://www.eonline.com/resize/300/484/akns-images.eonline.com/eol_images/Entire_Site/2010828/293.cruise.tom.lc.092810.jpg",
#                 "datePublished": "2017-10-13T10:42:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 484,
#                 "hostPageDisplayUrl": "www.eonline.com/news/tom_cruise",
#                 "hostPageDomainFriendlyName": "E News",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.aDDPL1aRP8PrYBknF4vrRQ&pid=Api",
#                 "hostPageUrl": "http://www.eonline.com/news/tom_cruise",
#                 "imageId": "FD4642497891AD70850BF280374589C17D95EB2D",
#                 "imageInsightsToken": "ccid_pm1cZMuV*mid_FD4642497891AD70850BF280374589C17D95EB2D*simid_608033318308351210*thid_OIP.pm1cZMuVCViq-EE1!_O0ZqwAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 3,
#                   "pagesIncludingCount": 10
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Tom Cruise News, Pictures, and Videos | E! News",
#                 "thumbnail": {
#                   "height": 484,
#                   "width": 300
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.pm1cZMuVCViq-EE1_O0ZqwAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=FD4642497891AD70850BF280374589C17D95EB2D&simid=608033318308351210",
#                 "width": 300
#               },
#               {
#                 "accentColor": "855946",
#                 "contentSize": "15301 B",
#                 "contentUrl": "https://images.radiotimes.com/remote/images.atlas.metabroadcast.com/pressassociation.com/webANXBritDarkTaboS6E4.jpg?quality=60&mode=crop&width=700&height=422",
#                 "datePublished": "2019-07-12T15:53:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 422,
#                 "hostPageDisplayUrl": "https://www.radiotimes.com/tv-programme/e/fpd26p/britains-darkest-taboos--s6-e4-he...",
#                 "hostPageDomainFriendlyName": "Radio Times",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.HVIMpkpJ5pX4_z5dj2pDfw&pid=Api",
#                 "hostPageUrl": "https://www.radiotimes.com/tv-programme/e/fpd26p/britains-darkest-taboos--s6-e4-he-trapped-our-sons-in-the-attic-then-set-fire-to-the-house/",
#                 "imageId": "A38135BF243822048DB81F8742601755797802AB",
#                 "imageInsightsToken": "ccid_ATg1zVip*mid_A38135BF243822048DB81F8742601755797802AB*simid_608021730501788430*thid_OIP.ATg1zVipi0BA1fGk5g!_hMAHaEd",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Britain's Darkest Taboos - what time is it on TV? Episode 4 Series 6 ...",
#                 "thumbnail": {
#                   "height": 285,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.ATg1zVipi0BA1fGk5g_hMAHaEd&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A38135BF243822048DB81F8742601755797802AB&simid=608021730501788430",
#                 "width": 700
#               },
#               {
#                 "accentColor": "977434",
#                 "contentSize": "43890 B",
#                 "contentUrl": "http://4.bp.blogspot.com/-PUeh4IUHNLc/Vlm-aYOLeFI/AAAAAAACaac/jMg1rmZR1N4/s1600/12193538_520152351480903_8398330799740972686_n.jpg",
#                 "datePublished": "2015-11-28T12:00:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 960,
#                 "hostPageDisplayUrl": "jovinsey.blogspot.com/2015/11/the-evolution-seventeen-hip-hop-unit.html",
#                 "hostPageDomainFriendlyName": "blogspot.com",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.kCKFU1-d0l3Elu2Vvbpmew&pid=Api",
#                 "hostPageUrl": "http://jovinsey.blogspot.com/2015/11/the-evolution-seventeen-hip-hop-unit.html",
#                 "imageId": "AD8BF92D47B5C9DEFFE2092DDF6B05634167C036",
#                 "imageInsightsToken": "ccid_DPNnqsj5*mid_AD8BF92D47B5C9DEFFE2092DDF6B05634167C036*simid_608006122563440188*thid_OIP.DPNnqsj5arbANxXnvOOejwHaKY",
#                 "insightsMetadata": {
#                   "availableSizesCount": 9,
#                   "pagesIncludingCount": 12
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "we don't give a what?: The Evolution: SEVENTEEN Hip Hop Unit",
#                 "thumbnail": {
#                   "height": 664,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP.DPNnqsj5arbANxXnvOOejwHaKY&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=AD8BF92D47B5C9DEFFE2092DDF6B05634167C036&simid=608006122563440188",
#                 "width": 685
#               },
#               {
#                 "accentColor": "546777",
#                 "contentSize": "63522 B",
#                 "contentUrl": "https://s-media-cache-ak0.pinimg.com/736x/3c/c9/9b/3cc99b45ed5aa06fc222c90dea296093.jpg",
#                 "datePublished": "2017-01-29T15:23:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1050,
#                 "hostPageDisplayUrl": "https://www.pinterest.com/pin/374221050268231068",
#                 "hostPageDomainFriendlyName": "Pinterest",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.PmATFqOwm9_sUEmusAtcwA&pid=Api",
#                 "hostPageUrl": "https://www.pinterest.com/pin/374221050268231068/",
#                 "imageId": "08E314D33456800E6EDEB2BB9B80A5C3FBB0B8E3",
#                 "imageInsightsToken": "ccid_AP4jKngI*mid_08E314D33456800E6EDEB2BB9B80A5C3FBB0B8E3*simid_608003313658233644*thid_OIP.AP4jKngIOb9tNyUAPTDn8AHaLH",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1,
#                   "recipeSourcesCount": 0
# ...
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Free & Premium Stock Photos - Canva",
#                 "thumbnail": {
#                   "height": 550,
#                   "width": 366
#                 },
#                 "thumbnailUrl": "https://tse4.mm.bing.net/th?id=OIP.PuoMS6dczw8cTy2CgRFTnAAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=F61EA963DE4CDA6166D91AD98BD025B854D655FD&simid=608027906633239904",
#                 "width": 366
#               },
#               {
#                 "accentColor": "886343",
#                 "contentSize": "97563 B",
#                 "contentUrl": "https://pbs.twimg.com/media/DF6EpgkUwAEr-L0.jpg",
#                 "datePublished": "2018-11-27T00:41:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1200,
#                 "hostPageDisplayUrl": "https://twitter.com/sd_bt/status/891295670933405696",
#                 "hostPageDomainFriendlyName": "Twitter",
#                 "hostPageUrl": "https://twitter.com/sd_bt/status/891295670933405696",
#                 "imageId": "91553153D794C164D2FEBA24C55BCB6953D4DE7E",
#                 "imageInsightsToken": "ccid_ifu6+nbZ*mid_91553153D794C164D2FEBA24C55BCB6953D4DE7E*simid_608047633448570022*thid_OIP.ifu6-nbZoWv!_6Ruc8cLLCQDYEg",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "\u8d85\u7279\u6025 OFFICIAL on Twitter: \"\u30cb\u30b3\u751f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\uff01 \u300c\u6771\u4eac\u55b0\u7a2e\u300d\u305f\u304f\u3055\u3093\u306e\u65b9\u306b\u898b\u3066\u6b32\u3057\u3044\u3067\u3059\uff01 \u5f15\u304d\u7d9a\u304d ...",
#                 "thumbnail": {
#                   "height": 632,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse1.mm.bing.net/th?id=OIP.ifu6-nbZoWv_6Ruc8cLLCQDYEg&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=91553153D794C164D2FEBA24C55BCB6953D4DE7E&simid=608047633448570022",
#                 "width": 900
#               },
#               {
#                 "accentColor": "82A328",
#                 "contentSize": "104705 B",
#                 "contentUrl": "https://thumbs.dreamstime.com/z/pregnant-young-women-men-studio-30104961.jpg",
#                 "datePublished": "2019-12-22T13:44:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1300,
#                 "hostPageDisplayUrl": "https://www.dreamstime.com/stock-image-pregnant-young-women-men-studio-image30104961",
#                 "hostPageUrl": "https://www.dreamstime.com/stock-image-pregnant-young-women-men-studio-image30104961",
#                 "imageId": "717812B6E545C2293651039343D6ED1C8DFCE5EC",
#                 "imageInsightsToken": "ccid_DDQqHJRW*mid_717812B6E545C2293651039343D6ED1C8DFCE5EC*simid_608052473855216249*thid_OIP.DDQqHJRWy0-4Ea2fCPzhnwHaKD",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Pregnant woman with man stock image. Image of caucasian - 30104961",
#                 "thumbnail": {
#                   "height": 643,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.DDQqHJRWy0-4Ea2fCPzhnwHaKD&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=717812B6E545C2293651039343D6ED1C8DFCE5EC&simid=608052473855216249",
#                 "width": 957
#               },
#               {
#                 "accentColor": "B59716",
#                 "contentSize": "61283 B",
#                 "contentUrl": "https://media.bizj.us/view/img/11346259/cieslak01*1200xx5472-3078-0-285.jpg",
#                 "datePublished": "2019-06-26T15:07:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 675,
#                 "hostPageDisplayUrl": "https://www.bizjournals.com/milwaukee/news/2019/06/26/lisa-cieslak-corporate-executive...",
#                 "hostPageDomainFriendlyName": "Business Journals",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.t3F4eXZUTDaqQci8YlUgMw&pid=Api",
#                 "hostPageUrl": "https://www.bizjournals.com/milwaukee/news/2019/06/26/lisa-cieslak-corporate-executive-a-people-person.html",
#                 "imageId": "F66A49767FA0C4FD4F9217DB5A159DFB1AFA5999",
#                 "imageInsightsToken": "ccid_+9SjH0x2*mid_F66A49767FA0C4FD4F9217DB5A159DFB1AFA5999*simid_608036518101190966*thid_OIP.-9SjH0x2Dz9tcLbtaITd6wHaEK",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Lisa Cieslak: Corporate Executive - Milwaukee Business Journal",
#                 "thumbnail": {
#                   "height": 266,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.-9SjH0x2Dz9tcLbtaITd6wHaEK&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=F66A49767FA0C4FD4F9217DB5A159DFB1AFA5999&simid=608036518101190966",
#                 "width": 1200
#               },
#               {
#                 "accentColor": "8C603F",
#                 "contentSize": "54016 B",
#                 "contentUrl": "https://images.garmentory.com/images/1141651/large/Sugar-Candy-Mountain---Irene-Top-in-Ivory-20180326190615.jpg?1522091180",
#                 "datePublished": "2018-04-07T10:18:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 840,
#                 "hostPageDisplayUrl": "https://www.garmentory.com/sale/sugar-candy-mountain/tops-blouses/280140-sugar-candy...",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.XHCRoCfybuK9DVBDnFhRew&pid=Api",
#                 "hostPageUrl": "https://www.garmentory.com/sale/sugar-candy-mountain/tops-blouses/280140-sugar-candy-mountain-irene-top-in-ivory",
#                 "imageId": "53ECECD44348AEDF7F8EAB344C6C62296089A906",
#                 "imageInsightsToken": "ccid_I8qHFbod*mid_53ECECD44348AEDF7F8EAB344C6C62296089A906*simid_608016619515544603*thid_OIP.I8qHFbodRD6XBsUM28edHQHaKX",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Sugar Candy Mountain Irene Top - Ivory | Garmentory",
#                 "thumbnail": {
#                   "height": 663,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.I8qHFbodRD6XBsUM28edHQHaKX&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=53ECECD44348AEDF7F8EAB344C6C62296089A906&simid=608016619515544603",
#                 "width": 600
#               },
#               {
#                 "accentColor": "A43627",
#                 "contentSize": "342444 B",
#                 "contentUrl": "https://i.pinimg.com/736x/fb/eb/3a/fbeb3ad577962520c7547ff72299b717--s-hair-s-fashion.jpg",
#                 "datePublished": "2018-06-08T07:12:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1024,
#                 "hostPageDisplayUrl": "https://www.pinterest.com/aaldridge0645/1959-hairstyles",
#                 "hostPageDomainFriendlyName": "Pinterest",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.PmATFqOwm9_sUEmusAtcwA&pid=Api",
#                 "hostPageUrl": "https://www.pinterest.com/aaldridge0645/1959-hairstyles/",
#                 "imageId": "817B90ACDF00FD69F6ED199D38C8D1103BAD5075",
#                 "imageInsightsToken": "ccid_5pVYmXr8*mid_817B90ACDF00FD69F6ED199D38C8D1103BAD5075*simid_608044691398919897*thid_OIP.5pVYmXr8rH8b0lJ-tQpMuAHaLC",
#                 "insightsMetadata": {
#                   "availableSizesCount": 5,
#                   "pagesIncludingCount": 9
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "17 best 1959 Hairstyles images on Pinterest | Fashion vintage, Vintage ...",
#                 "thumbnail": {
#                   "height": 706,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.5pVYmXr8rH8b0lJ-tQpMuAHaLC&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=817B90ACDF00FD69F6ED199D38C8D1103BAD5075&simid=608044691398919897",
#                 "width": 687
#               },
#               {
#                 "accentColor": "8E623D",
#                 "contentSize": "11126 B",
#                 "contentUrl": "https://s-media-cache-ak0.pinimg.com/236x/27/66/76/276676746e4456538ca8ae8f06925f81.jpg",
#                 "datePublished": "2016-12-31T22:05:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 314,
#                 "hostPageDisplayUrl": "https://www.pinterest.com/coscouture/movie-cosplays",
#                 "hostPageDomainFriendlyName": "Pinterest",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.PmATFqOwm9_sUEmusAtcwA&pid=Api",
#                 "hostPageUrl": "https://www.pinterest.com/coscouture/movie-cosplays/",
#                 "imageId": "5C67587212842C39B92CDF84A6BF0C6730B10BC3",
#                 "imageInsightsToken": "ccid_Sb/aT71Y*mid_5C67587212842C39B92CDF84A6BF0C6730B10BC3*simid_608053062267112274*thid_OIP.Sb!_aT71Y1JXT8KG2B7VGaQAAAA",
#                 "insightsMetadata": {
#                   "availableSizesCount": 3,
#                   "pagesIncludingCount": 3
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "1000+ images about Movie Cosplays on Pinterest | Cosplay, Jessica ...",
#                 "thumbnail": {
#                   "height": 314,
#                   "width": 236
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.Sb_aT71Y1JXT8KG2B7VGaQAAAA&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=5C67587212842C39B92CDF84A6BF0C6730B10BC3&simid=608053062267112274",
#                 "width": 236
#               },
#               {
#                 "accentColor": "446187",
#                 "contentSize": "20542 B",
#                 "contentUrl": "https://dentaltempsprofessionalservices.com/wp-content/uploads/dental-temps-232.jpg",
#                 "datePublished": "2019-11-17T21:50:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 387,
#                 "hostPageDisplayUrl": "https://dentaltempsprofessionalservices.com/dental-assistant-prepare-patient-personal...",
#                 "hostPageUrl": "https://dentaltempsprofessionalservices.com/dental-assistant-prepare-patient-personal-document/",
#                 "imageId": "9D00744FE64605FC2D850FECC2BE98D2D7557DF4",
#                 "imageInsightsToken": "ccid_qI49RCzf*mid_9D00744FE64605FC2D850FECC2BE98D2D7557DF4*simid_608043231107091086*thid_OIP.qI49RCzfA7aRYxiW1868QQHaD3",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 1
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "Dental assistant prepare patient personal document - Dental Temps",
#                 "thumbnail": {
#                   "height": 247,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse2.mm.bing.net/th?id=OIP.qI49RCzfA7aRYxiW1868QQHaD3&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=9D00744FE64605FC2D850FECC2BE98D2D7557DF4&simid=608043231107091086",
#                 "width": 740
#               },
#               {
#                 "accentColor": "925839",
#                 "contentSize": "150773 B",
#                 "contentUrl": "http://static1.bigstockphoto.com/thumbs/7/4/1/large1500/147802679.jpg",
#                 "datePublished": "2017-10-09T21:31:00.0000000Z",
#                 "encodingFormat": "jpeg",
#                 "height": 1620,
#                 "hostPageDisplayUrl": "www.bigstockphoto.com/image-147802679/stock-photo-young-female-optometrist-working-in...",
#                 "hostPageDomainFriendlyName": "Bigstock",
#                 "hostPageFavIconUrl": "https://www.bing.com/th?id=ODF.IA5U0m2koeiOu1h8OJVVHQ&pid=Api",
#                 "hostPageUrl": "http://www.bigstockphoto.com/image-147802679/stock-photo-young-female-optometrist-working-in-studio-lab",
#                 "imageId": "A9296E208781A3B91FF1D10BDA63B8C2335AB4CB",
#                 "imageInsightsToken": "ccid_X3bb2FWY*mid_A9296E208781A3B91FF1D10BDA63B8C2335AB4CB*simid_608023491422914431*thid_OIP.X3bb2FWYlJZuErk3EoJISwHaL!_",
#                 "insightsMetadata": {
#                   "availableSizesCount": 1,
#                   "pagesIncludingCount": 2
#                 },
#                 "isFamilyFriendly": true,
#                 "name": "young female optometrist working in studio lab Stock Photo & Stock ...",
#                 "thumbnail": {
#                   "height": 767,
#                   "width": 474
#                 },
#                 "thumbnailUrl": "https://tse3.mm.bing.net/th?id=OIP.X3bb2FWYlJZuErk3EoJISwHaL_&pid=Api",
#                 "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A9296E208781A3B91FF1D10BDA63B8C2335AB4CB&simid=608023491422914431",
#                 "width": 1000
#               }
#             ]
#           }
#         },
#         {
#           "actionType": "ImageById",
#           "image": {
#             "contentSize": "86211 B",
#             "encodingFormat": "jpeg",
#             "height": 1024,
#             "hostPageDisplayUrl": "",
#             "isFamilyFriendly": true,
#             "name": "",
#             "thumbnail": {
#               "height": 0,
#               "width": 0
#             },
#             "visualWords": "7bfc1 8e4ce f2d40 d8f30 0ea24 d7b64 8f7e6 9a37d d4fc4 56d98 c5b36 8605c 8b010 ce96b 8f81b 9a2d4 603c2 7d5aa d7935 8c467 06813982404681f87f4738bccaeb3000df7a5a8738b0f44d42506c311ce4aedb960989996a8d0d1a9c245c4f7ba0c9e3fc56",
#             "webSearchUrl": "https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO",
#             "width": 576
#           }
#         }
#       ],
#       "displayName": ""
#     },
#     {
#       "actions": [
#         {
#           "_type": "ImageModuleAction",
#           "actionType": "VisualSearch"
#         },
#         {
#           "_type": "ImageModuleAction",
#           "actionType": "ProductVisualSearch"
#         }
#       ],
#       "boundingBox": {
#         "displayRectangle": {
#           "bottomLeft": {
#             "x": 0.71520007,
#             "y": 0.63918203
#           },
#           "bottomRight": {
#             "x": 0.71520007,
#             "y": 0.63918203
#           },
#           "topLeft": {
#             "x": 0.71520007,
#             "y": 0.63918203
#           },
#           "topRight": {
#             "x": 0.71520007,
#             "y": 0.63918203
#           }
#         },
#         "queryRectangle": {
#           "bottomLeft": {
#             "x": 0.4321363,
#             "y": 0.99337435
#           },
#           "bottomRight": {
#             "x": 0.9982639,
#             "y": 0.99337435
#           },
#           "topLeft": {
#             "x": 0.4321363,
#             "y": 0.2849897
#           },
#           "topRight": {
#             "x": 0.9982639,
#             "y": 0.2849897
#           }
#         }
#       },
#       "displayName": "Button-down shirt",
#       "image": {
#         "thumbnailUrl": "https://tse4.mm.bing.net/th?q=Button-down+shirt&pid=Api&mkt=en-IN&adlt=moderate"
#       }
#     }
#   ]
# }
